# %% [markdown]
# # Decoding Sector Valuation Dynamics
#
# Exploring the Nexus of Company Fundamentals, Economic Indicators, and Equity Valuations via Predictive Analytics

# %% [markdown]
# ## Data Preprocessing

# %%
import pandas as pd
import numpy as np

# Constants (525 weeks or about 10 years)
DATE_START = pd.to_datetime('2014-01-25')
DATE_END = pd.to_datetime('2024-02-17')
# Offset the start date by 2 quarters
# Useful for calculating the % change before the start date
DATE_START_OFFSET = DATE_START - pd.DateOffset(weeks=26)

# %% [markdown]
# ### Retrieve Data
#
# #### Financials

# %%
# Load financials and assign cap

def load_financials(cap: str) -> pd.DataFrame:
    df: pd.DataFrame = pd.read_csv(f'data/{cap}/financials_q.csv')
    df['cap'] = cap
    return df


df: pd.DataFrame = pd.concat([load_financials(cap)
                             for cap in ['large', 'mid', 'small']])
df['asOfDate'] = pd.to_datetime(df['asOfDate'])

# Insert GICS sector for each symbol
df_gics: pd.DataFrame = pd.concat([pd.read_csv(
    f'data/{cap}/tickers+GICS.csv') for cap in ['large', 'mid', 'small']])
df = pd.merge(df, df_gics, left_on='symbol', right_on='Symbol')
# %xdel df_gics

df.drop(columns=['Symbol'], inplace=True)

# Show empty GICS Sub-Industry Companies
display(df[df['GICS Sub-Industry'].isnull()][['symbol', 'GICS Sector']].drop_duplicates())

print('Total Filings:', df.shape)
df.tail()
# Out:
#       symbol             GICS Sector
# 61741   ALLY              Financials
# 73999    FNF              Financials
# 74631   GDDY  Information Technology
# 75092   GLPI             Real Estate
# 82755   MORN              Financials
# 83377    MTN  Consumer Discretionary
# 89133     PR                  Energy
# 89902    RBC             Industrials
# 94249     ST             Industrials
# 99277   WFRD                  Energy
# Total Filings: (159841, 345)
#        symbol   asOfDate periodType currencyCode  AccountsPayable  \
# 159836   ZEUS 2022-09-30         3M          USD      167081000.0
# 159837   ZEUS 2022-12-31         3M          USD      101446000.0
# 159838   ZEUS 2023-03-31         3M          USD      142608000.0
# 159839   ZEUS 2023-06-30         3M          USD      124087000.0
# 159840   ZEUS 2023-09-30         3M          USD      127671000.0
#
#         AccountsReceivable  AccruedInterestReceivable  \
# 159836         279344000.0                        NaN
# 159837         219789000.0                        NaN
# 159838         236844000.0                        NaN
# 159839         227992000.0                        NaN
# 159840         227847000.0                        NaN
#
#         AccumulatedDepreciation  AdditionalPaidInCapital  \
# 159836             -293845000.0                      NaN
# 159837             -299241000.0                      NaN
# 159838             -301696000.0                      NaN
# 159839             -307118000.0                      NaN
# 159840             -312384000.0                      NaN
#
#         AdjustedGeographySegmentData  ...  TreasuryStock  UnrealizedGainLoss  \
# 159836                           NaN  ...            NaN                 NaN
# 159837                           NaN  ...            0.0                 NaN
# 159838                           NaN  ...            NaN                 NaN
# 159839                           NaN  ...            NaN                 NaN
# 159840                           NaN  ...            NaN                 NaN
#
#         UnrealizedGainLossOnInvestmentSecurities  WorkInProcess  \
# 159836                                       NaN            NaN
# 159837                                       NaN            NaN
# 159838                                       NaN            NaN
# 159839                                       NaN            NaN
# 159840                                       NaN            NaN
#
#         WorkingCapital  WriteOff    cap  Security  GICS Sector  \
# 159836     574409000.0       NaN  small       NaN    Materials
# 159837     493404000.0       NaN  small       NaN    Materials
# 159838     481492000.0       NaN  small       NaN    Materials
# 159839     481824000.0       NaN  small       NaN    Materials
# 159840     455528000.0       NaN  small       NaN    Materials
#
#         GICS Sub-Industry
# 159836              Steel
# 159837              Steel
# 159838              Steel
# 159839              Steel
# 159840              Steel
#
# [5 rows x 345 columns]

# %%
# Several are missing GICS Sub-Industry
# We will fill these in manually using revenue information from their 10-K filings

# According to ALLY's 10-K, they derive the majority of their revenue from Automotive Finance and Insurance operations (Consumer Finance)
df.loc[df['symbol'] == 'ALLY', 'GICS Sub-Industry'] = 'Consumer Finance'

# FNF derives the majority of its revenue from Title Insurance according to their 10-K
df.loc[df['symbol'] == 'FNF', 'GICS Sub-Industry'] = 'Property & Casualty Insurance'

# GDDY derives the majority of its revenue from Applications and Commerce (proprietary website software and POS fees)
df.loc[df['symbol'] == 'GDDY', 'GICS Sub-Industry'] = 'Internet Services & Infrastructure'

# GLPI is a REIT specializing in Gaming and Leisure (Casinos, and Resorts/Spas)
df.loc[df['symbol'] == 'GLPI', 'GICS Sub-Industry'] = 'Hotel & Resort REITs'

# MORN derives the majority of its revenue from Investment Research and Management data
df.loc[df['symbol'] == 'MORN', 'GICS Sub-Industry'] = 'Financial Exchanges & Data'

# MTN derives the majority of its revenue from Ski tickets at their resorts
df.loc[df['symbol'] == 'MTN', 'GICS Sub-Industry'] = 'Leisure Facilities'

# PR derives the majority of its revenue from Oil & Gas sales
df.loc[df['symbol'] == 'PR', 'GICS Sub-Industry'] = 'Oil & Gas Exploration & Productions'

# RBC derives the majority of its revenue from bearings and precision components
df.loc[df['symbol'] == 'RBC',
       'GICS Sub-Industry'] = 'Industrial Machinery & Supplies & Components'

# ST has a majority of its revenue from sensor based products
df.loc[df['symbol'] == 'ST', 'GICS Sub-Industry'] = 'Electronic Components'

# WFRD derives the majority of its revenue from their oil & gas related services and equipment
df.loc[df['symbol'] == 'WFRD', 'GICS Sub-Industry'] = 'Oil & Gas Equipment & Services' 

# GICS Information
df_gics_info: pd.DataFrame = pd.read_csv('data/gics.csv')

# Check for differences between GICS Sub-Industry names
display(df[~df['GICS Sub-Industry'].isin(df_gics_info['GICS Sub-Industry'])][['GICS Sector', 'GICS Sub-Industry']].drop_duplicates())
# Out:
#                    GICS Sector                      GICS Sub-Industry
# 63216                Materials               Metal & Glass Containers
# 64340                Materials                        Paper Packaging
# 64424         Consumer Staples           Hypermarkets & Super Centers
# 66453         Consumer Staples                            Soft Drinks
# 68770         Consumer Staples                      Personal Products
# 69952         Consumer Staples                  Agricultural Products
# 70098              Industrials                   Industrial Machinery
# 70515   Consumer Discretionary                       Specialty Stores
# 74326              Industrials  Construction Machinery & Heavy Trucks
# 79108              Industrials                                 Marine
# 82547   Information Technology                Semiconductor Equipment
# 89133                   Energy    Oil & Gas Exploration & Productions
# 103774             Industrials                               Airlines
# 107384  Consumer Discretionary                 Auto Parts & Equipment
# 120596             Real Estate                      Specialized REITs

# %% [markdown]
# Several Sub-Industries appear to have slightly different names between the two datasets.

# %%
# Metal & Glass Containers to Metal, Glass & Plastic Containers
df.loc[df['GICS Sub-Industry'] == 'Metal & Glass Containers', 'GICS Sub-Industry'] = 'Metal, Glass & Plastic Containers'
# Paper Packaging to Paper & Plastic Packaging Products & Materials
df.loc[df['GICS Sub-Industry'] == 'Paper Packaging', 'GICS Sub-Industry'] = 'Paper & Plastic Packaging Products & Materials'

# Check Hypermarkets & Super Centers tickers
df[df['GICS Sub-Industry'] == 'Hypermarkets & Super Centers']['symbol'].unique()
# Out:
# array(['BJ', 'PSMT'], dtype=object)

# %%
# Hypermarkets & Super Centers to Consumer Staples Merchandise Retail
df.loc[df['GICS Sub-Industry'] == 'Hypermarkets & Super Centers', 'GICS Sub-Industry'] = 'Consumer Staples Merchandise Retail'

# Soft Drinks to Soft Drinks & Non-alcoholic Beverages
df.loc[df['GICS Sub-Industry'] == 'Soft Drinks', 'GICS Sub-Industry'] = 'Soft Drinks & Non-alcoholic Beverages'

# Personal Products to Personal Care Products
df.loc[df['GICS Sub-Industry'] == 'Personal Products', 'GICS Sub-Industry'] = 'Personal Care Products'

# Agricultural Products to Agricultural Products & Services
df.loc[df['GICS Sub-Industry'] == 'Agricultural Products', 'GICS Sub-Industry'] = 'Agricultural Products & Services'

# Industrial Machinery to Industrial Machinery & Supplies & Components
df.loc[df['GICS Sub-Industry'] == 'Industrial Machinery', 'GICS Sub-Industry'] = 'Industrial Machinery & Supplies & Components'

# Specialty Stores to Other Specialty Retail
df.loc[df['GICS Sub-Industry'] == 'Specialty Stores', 'GICS Sub-Industry'] = 'Other Specialty Retail'

# Construction Machinery & Heavy Trucks to Construction Machinery & Heavy Transportation Equipment
df.loc[df['GICS Sub-Industry'] == 'Construction Machinery & Heavy Trucks', 'GICS Sub-Industry'] = 'Construction Machinery & Heavy Transportation Equipment'

# Marine to Marine Transportation
df.loc[df['GICS Sub-Industry'] == 'Marine', 'GICS Sub-Industry'] = 'Marine Transportation'

# Semiconductor Equipment to Semiconductor Materials & Equipment
df.loc[df['GICS Sub-Industry'] == 'Semiconductor Equipment', 'GICS Sub-Industry'] = 'Semiconductor Materials & Equipment'

# Oil & Gas Exploration & Productions to Oil & Gas Exploration & Production
df.loc[df['GICS Sub-Industry'] == 'Oil & Gas Exploration & Productions', 'GICS Sub-Industry'] = 'Oil & Gas Exploration & Production'

# Airlines to Passenger Airlines
df.loc[df['GICS Sub-Industry'] == 'Airlines', 'GICS Sub-Industry'] = 'Passenger Airlines'

# Auto Parts & Equipment to Automotive Parts & Equipment
df.loc[df['GICS Sub-Industry'] == 'Auto Parts & Equipment', 'GICS Sub-Industry'] = 'Automotive Parts & Equipment'

# Specialized REITs to Other Specialized REITs
df.loc[df['GICS Sub-Industry'] == 'Specialized REITs', 'GICS Sub-Industry'] = 'Other Specialized REITs'

# Merge
df = pd.merge(df, df_gics_info, on='GICS Sub-Industry', how='left')

# Drop extra GICS Sector
df.drop(columns=['GICS Sector_y'], inplace=True)
df.rename(columns={'GICS Sector_x': 'GICS Sector'}, inplace=True)

# Display number of nulls
with pd.option_context('display.max_rows', None):
    display(df.isnull().sum())
# Out:
# symbol                                                               0
# asOfDate                                                             0
# periodType                                                           0
# currencyCode                                                         0
# AccountsPayable                                                  31151
# AccountsReceivable                                               48688
# AccruedInterestReceivable                                       158538
# AccumulatedDepreciation                                          55623
# AdditionalPaidInCapital                                          47167
# AdjustedGeographySegmentData                                    159795
# AllowanceForDoubtfulAccountsReceivable                          126321
# Amortization                                                    137484
# AmortizationCashFlow                                            130281
# AmortizationOfIntangibles                                       130337
# AmortizationOfIntangiblesIncomeStatement                        138165
# AmortizationOfSecurities                                        144730
# AssetImpairmentCharge                                           136158
# AssetsHeldForSaleCurrent                                        149822
# AvailableForSaleSecurities                                      143604
# AverageDilutionEarnings                                         153397
# BasicAverageShares                                               26115
# BasicEPS                                                         25873
# BeginningCashPosition                                            14022
# BuildingsAndImprovements                                        128075
# CapitalExpenditure                                               20829
# CapitalExpenditureReported                                      127921
# CapitalLeaseObligations                                         130126
# CapitalStock                                                     34188
# CashAndCashEquivalents                                           12953
# CashCashEquivalentsAndShortTermInvestments                       26976
# CashDividendsPaid                                                62092
# CashEquivalents                                                 152958
# CashFinancial                                                   150558
# CashFlowFromContinuingFinancingActivities                        12074
# CashFlowFromContinuingInvestingActivities                        12110
# CashFlowFromContinuingOperatingActivities                        12877
# CashFlowFromDiscontinuedOperation                               158530
# CashFlowsfromusedinOperatingActivitiesDirect                    159719
# CashFromDiscontinuedFinancingActivities                         157034
# CashFromDiscontinuedInvestingActivities                         154253
# CashFromDiscontinuedOperatingActivities                         150298
# ChangeInAccountPayable                                          100725
# ChangeInAccruedExpense                                          126317
# ChangeInCashSupplementalAsReported                               11918
# ChangeInDividendPayable                                         159777
# ChangeInIncomeTaxPayable                                        136113
# ChangeInInterestPayable                                         156442
# ChangeInInventory                                                83003
# ChangeInOtherCurrentAssets                                       99253
# ChangeInOtherCurrentLiabilities                                  93534
# ChangeInOtherWorkingCapital                                      82627
# ChangeInPayable                                                  92531
# ChangeInPayablesAndAccruedExpense                                45104
# ChangeInPrepaidAssets                                           114447
# ChangeInReceivables                                              46223
# ChangeInTaxPayable                                              136107
# ChangeInWorkingCapital                                           18585
# ChangesInAccountReceivables                                      99572
# ChangesInCash                                                    14839
# ClassesofCashPayments                                           159726
# ClassesofCashReceiptsfromOperatingActivities                    159727
# CommercialPaper                                                 156292
# CommonStock                                                      34926
# CommonStockDividendPaid                                         114248
# CommonStockEquity                                                10201
# CommonStockIssuance                                              86943
# CommonStockPayments                                              80276
# ConstructionInProgress                                          132201
# CostOfRevenue                                                    36698
# CurrentAccruedExpenses                                           71818
# CurrentAssets                                                    34155
# CurrentCapitalLeaseObligation                                   141493
# CurrentDebt                                                      56041
# CurrentDebtAndCapitalLeaseObligation                             49868
# CurrentDeferredAssets                                           121607
# CurrentDeferredLiabilities                                      116924
# CurrentDeferredRevenue                                          122272
# CurrentDeferredTaxesAssets                                      124078
# CurrentDeferredTaxesLiabilities                                 152997
# CurrentLiabilities                                               34165
# CurrentNotesPayable                                             148852
# CurrentProvisions                                               152783
# DeferredIncomeTax                                                64780
# DeferredTax                                                      64780
# DefinedPensionBenefit                                           156040
# Depletion                                                       159385
# DepletionIncomeStatement                                        159762
# Depreciation                                                    120169
# DepreciationAmortizationDepletion                                24149
# DepreciationAmortizationDepletionIncomeStatement                 82745
# DepreciationAndAmortization                                      25427
# DepreciationAndAmortizationInIncomeStatement                     85885
# DepreciationIncomeStatement                                     150793
# DerivativeProductLiabilities                                    152539
# DilutedAverageShares                                             26120
# DilutedEPS                                                       25873
# DilutedNIAvailtoComStockholders                                   7710
# DividendPaidCFO                                                 159779
# DividendReceivedCFO                                             153725
# DividendsPayable                                                147929
# DividendsReceivedCFI                                            155523
# DomesticSales                                                   159499
# DuefromRelatedPartiesCurrent                                    157134
# DuefromRelatedPartiesNonCurrent                                 159495
# DuetoRelatedPartiesCurrent                                      157309
# DuetoRelatedPartiesNonCurrent                                   159331
# EBIT                                                             17141
# EBITDA                                                           22459
# EarningsFromEquityInterest                                      139036
# EarningsFromEquityInterestNetOfTax                              151380
# EarningsLossesFromEquityInvestments                             139150
# EffectOfExchangeRateChanges                                      90219
# EmployeeBenefits                                                136609
# EndCashPosition                                                  14738
# ExcessTaxBenefitFromStockBasedCompensation                      145513
# ExciseTaxes                                                     159040
# FinancialAssets                                                 155710
# FinancialAssetsDesignatedasFairValueThroughProfitorLossTotal    159535
# FinancingCashFlow                                                11869
# FinishedGoods                                                   112206
# FixedAssetsRevaluationReserve                                   159810
# ForeignCurrencyTranslationAdjustments                           152880
# ForeignSales                                                    159500
# FreeCashFlow                                                     11763
# GainLossOnInvestmentSecurities                                  132475
# GainLossOnSaleOfBusiness                                        151293
# GainLossOnSaleOfPPE                                             139855
# GainOnSaleOfBusiness                                            153845
# GainOnSaleOfPPE                                                 149345
# GainOnSaleOfSecurity                                            129204
# GainsLossesNotAffectingRetainedEarnings                          48241
# GeneralAndAdministrativeExpense                                 108223
# GeneralPartnershipCapital                                       159809
# Goodwill                                                         84740
# GoodwillAndOtherIntangibleAssets                                 45994
# GrossAccountsReceivable                                         121324
# GrossPPE                                                         44237
# GrossProfit                                                      36686
# HedgingAssetsCurrent                                            155691
# HeldToMaturitySecurities                                        153961
# ImpairmentOfCapitalAssets                                       145102
# IncomeTaxPaidSupplementalData                                   123546
# IncomeTaxPayable                                                130997
# InsuranceAndClaims                                              153229
# InterestExpense                                                  75248
# InterestExpenseNonOperating                                      89832
# InterestIncome                                                  108034
# InterestIncomeNonOperating                                      123171
# InterestPaidCFF                                                 159508
# InterestPaidCFO                                                 159737
# InterestPaidSupplementalData                                    120664
# InterestPayable                                                 144663
# InterestReceivedCFI                                             159467
# InterestReceivedCFO                                             159788
# InventoriesAdjustmentsAllowances                                148657
# Inventory                                                        61619
# InvestedCapital                                                  10750
# InvestingCashFlow                                                11877
# InvestmentProperties                                            154998
# InvestmentinFinancialAssets                                     151784
# InvestmentsAndAdvances                                          106709
# InvestmentsInOtherVenturesUnderEquityMethod                     157349
# InvestmentsinAssociatesatCost                                   155471
# InvestmentsinJointVenturesatCost                                157127
# InvestmentsinSubsidiariesatCost                                 159284
# IssuanceOfCapitalStock                                           85631
# IssuanceOfDebt                                                   90028
# LandAndImprovements                                             126436
# Leases                                                          145877
# LiabilitiesHeldforSaleNonCurrent                                157241
# LimitedPartnershipCapital                                       159788
# LineOfCredit                                                    150515
# LoansReceivable                                                 156354
# LongTermCapitalLeaseObligation                                  131480
# LongTermDebt                                                     30126
# LongTermDebtAndCapitalLeaseObligation                            25758
# LongTermDebtIssuance                                             95677
# LongTermDebtPayments                                             79758
# LongTermEquityInvestment                                        142795
# LongTermProvisions                                              151828
# MachineryFurnitureEquipment                                     118301
# MinimumPensionLiabilities                                       157911
# MinorityInterest                                                109326
# MinorityInterests                                               111823
# NetBusinessPurchaseAndSale                                       94508
# NetCommonStockIssuance                                           40201
# NetDebt                                                          49251
# NetForeignCurrencyExchangeGainLoss                              153302
# NetIncome                                                         7707
# NetIncomeCommonStockholders                                       7707
# NetIncomeContinuousOperations                                      441
# NetIncomeDiscontinuousOperations                                134855
# NetIncomeExtraordinary                                          156825
# NetIncomeFromContinuingAndDiscontinuedOperation                   7707
# NetIncomeFromContinuingOperationNetMinorityInterest               7708
# NetIncomeFromContinuingOperations                                15079
# NetIncomeFromTaxLossCarryforward                                158057
# NetIncomeIncludingNoncontrollingInterests                          440
# NetIntangiblesPurchaseAndSale                                   149882
# NetInterestIncome                                                69065
# NetInvestmentPropertiesPurchaseAndSale                          152131
# NetInvestmentPurchaseAndSale                                     78708
# NetIssuancePaymentsOfDebt                                        28108
# NetLongTermDebtIssuance                                          74962
# NetNonOperatingInterestIncomeExpense                             83636
# NetOtherFinancingCharges                                         59272
# NetOtherInvestingChanges                                         63411
# NetPPE                                                           17463
# NetPPEPurchaseAndSale                                            35682
# NetPreferredStockIssuance                                       154268
# NetShortTermDebtIssuance                                        111952
# NetTangibleAssets                                                10201
# NonCurrentAccountsReceivable                                    153548
# NonCurrentAccruedExpenses                                       154832
# NonCurrentDeferredAssets                                        112991
# NonCurrentDeferredLiabilities                                    68713
# NonCurrentDeferredRevenue                                       144224
# NonCurrentDeferredTaxesAssets                                   121521
# NonCurrentDeferredTaxesLiabilities                               77470
# NonCurrentNoteReceivables                                       154535
# NonCurrentPensionAndOtherPostretirementBenefitPlans             140351
# NonCurrentPrepaidAssets                                         153901
# NormalizedEBITDA                                                 22459
# NormalizedIncome                                                  7707
# NotesReceivable                                                 155847
# OperatingCashFlow                                                11835
# OperatingExpense                                                 32012
# OperatingGainsLosses                                             58803
# OperatingIncome                                                  22222
# OperatingRevenue                                                  1459
# OrdinarySharesNumber                                             11440
# OtherCapitalStock                                               155114
# OtherCashAdjustmentInsideChangeinCash                           158735
# OtherCashAdjustmentOutsideChangeinCash                          138778
# OtherCashPaymentsfromOperatingActivities                        159741
# OtherCashReceiptsfromOperatingActivities                        159727
# OtherCurrentAssets                                               68225
# OtherCurrentBorrowings                                          124747
# OtherCurrentLiabilities                                          83690
# OtherEquityAdjustments                                          108307
# OtherEquityInterest                                             123806
# OtherGandA                                                      121159
# OtherIncomeExpense                                               47165
# OtherIntangibleAssets                                            65355
# OtherInventories                                                149933
# OtherInvestments                                                153918
# OtherNonCashItems                                                51316
# OtherNonCurrentAssets                                            42069
# OtherNonCurrentLiabilities                                       59036
# OtherNonOperatingIncomeExpenses                                 117101
# OtherOperatingExpenses                                          123041
# OtherPayable                                                    144071
# OtherProperties                                                 119335
# OtherReceivables                                                127823
# OtherShortTermInvestments                                       114220
# OtherSpecialCharges                                             138922
# OtherTaxes                                                      147958
# OtherunderPreferredStockDividend                                146824
# Payables                                                         26827
# PayablesAndAccruedExpenses                                       21141
# PaymentsonBehalfofEmployees                                     159778
# PensionAndEmployeeBenefitExpense                                148899
# PensionandOtherPostRetirementBenefitPlansCurrent                134297
# PreferredSecuritiesOutsideStockEquity                           149842
# PreferredSharesNumber                                           150410
# PreferredStock                                                  104684
# PreferredStockDividendPaid                                      152896
# PreferredStockDividends                                         142876
# PreferredStockEquity                                            142454
# PreferredStockIssuance                                          156701
# PreferredStockPayments                                          157188
# PrepaidAssets                                                    93830
# PretaxIncome                                                     16458
# ProceedsFromStockOptionExercised                                116697
# Properties                                                      121457
# ProvisionForDoubtfulAccounts                                    157714
# ProvisionandWriteOffofAssets                                    142649
# PurchaseOfBusiness                                              114212
# PurchaseOfIntangibles                                           150644
# PurchaseOfInvestment                                             91634
# PurchaseOfInvestmentProperties                                  154785
# PurchaseOfPPE                                                    50706
# RawMaterials                                                    114255
# Receivables                                                      18459
# ReceivablesAdjustmentsAllowances                                154107
# ReconciledCostOfRevenue                                          36691
# ReconciledDepreciation                                           18074
# RentAndLandingFees                                              156564
# RentExpenseSupplemental                                         153861
# RepaymentOfDebt                                                  76960
# RepurchaseOfCapitalStock                                         79206
# ResearchAndDevelopment                                          126232
# RestrictedCash                                                  140454
# RestrictedCommonStock                                           159687
# RestructuringAndMergernAcquisition                              127987
# RetainedEarnings                                                 12864
# SalariesAndWages                                                133941
# SaleOfBusiness                                                  143350
# SaleOfIntangibles                                               158938
# SaleOfInvestment                                                 91571
# SaleOfInvestmentProperties                                      153916
# SaleOfPPE                                                       109427
# SecuritiesAmortization                                          159202
# SellingAndMarketingExpense                                      135821
# SellingGeneralAndAdministration                                  22866
# ShareIssued                                                      11440
# ShortTermDebtIssuance                                           138592
# ShortTermDebtPayments                                           138000
# SpecialIncomeCharges                                             60173
# StockBasedCompensation                                           89198
# StockholdersEquity                                               10201
# TangibleBookValue                                                10202
# TaxEffectOfUnusualItems                                           7707
# TaxProvision                                                     19463
# TaxRateForCalcs                                                   7707
# TaxesReceivable                                                 144279
# TaxesRefundPaid                                                 159503
# TotalAssets                                                      10200
# TotalCapitalization                                              11253
# TotalDebt                                                        22071
# TotalEquityGrossMinorityInterest                                 10201
# TotalExpenses                                                    25692
# TotalLiabilitiesNetMinorityInterest                              10200
# TotalNonCurrentAssets                                            34173
# TotalNonCurrentLiabilitiesNetMinorityInterest                    39263
# TotalOperatingIncomeAsReported                                   57263
# TotalOtherFinanceCost                                           146295
# TotalPartnershipCapital                                         159755
# TotalRevenue                                                      1459
# TotalTaxPayable                                                 119672
# TotalUnusualItems                                                53427
# TotalUnusualItemsExcludingGoodwill                               53441
# TradeandOtherPayablesNonCurrent                                 150321
# TradingSecurities                                               155403
# TreasurySharesNumber                                            116712
# TreasuryStock                                                    93089
# UnrealizedGainLoss                                              158247
# UnrealizedGainLossOnInvestmentSecurities                        155614
# WorkInProcess                                                   123743
# WorkingCapital                                                   34165
# WriteOff                                                        152436
# cap                                                                  0
# Security                                                         58715
# GICS Sector                                                          0
# GICS Sub-Industry                                                    0
# GICS Sector ID                                                       0
# GICS Industry Group ID                                               0
# GICS Industry Group                                                  0
# GICS Industry ID                                                     0
# GICS Industry                                                        0
# GICS Sub-Industry ID                                                 0
# dtype: int64

# %%
# View sectors, sector groups, and Industry, and sub-industry
with pd.option_context('display.max_rows', None):
	display(df.groupby(['GICS Sector', 'GICS Industry Group', 'GICS Industry', 'GICS Sub-Industry']).size())
# Out:
# GICS Sector             GICS Industry Group                             GICS Industry                                          GICS Sub-Industry
# Communication Services  Media & Entertainment                           Entertainment                                          Interactive Home Entertainment                               247
#                                                                                                                                Movies & Entertainment                                       650
#                                                                         Interactive Media & Services                           Interactive Media & Services                                 752
#                                                                         Media                                                  Advertising                                                  406
#                                                                                                                                Broadcasting                                                 284
#                                                                                                                                Cable & Satellite                                            293
#                                                                                                                                Publishing                                                   406
#                         Telecommunication Services                      Diversified Telecommunication Services                 Alternative Carriers                                         302
#                                                                                                                                Integrated Telecommunication Services                        679
#                                                                         Wireless Telecommunication Services                    Wireless Telecommunication Services                          291
# Consumer Discretionary  Automobiles & Components                        Automobile Components                                  Automotive Parts & Equipment                                1782
#                                                                                                                                Tires & Rubber                                               154
#                                                                         Automobiles                                            Automobile Manufacturers                                     429
#                                                                                                                                Motorcycle Manufacturers                                     153
#                         Consumer Discretionary Distribution & Retail    Broadline Retail                                       Broadline Retail                                             706
#                                                                         Distributors                                           Distributors                                                 402
#                                                                         Specialty Retail                                       Apparel Retail                                              1674
#                                                                                                                                Automotive Retail                                           1511
#                                                                                                                                Computer & Electronics Retail                                362
#                                                                                                                                Home Improvement Retail                                      359
#                                                                                                                                Homefurnishing Retail                                        391
#                                                                                                                                Other Specialty Retail                                      1278
#                         Consumer Durables & Apparel                     Household Durables                                     Consumer Electronics                                         122
#                                                                                                                                Home Furnishings                                             644
#                                                                                                                                Homebuilding                                                1698
#                                                                                                                                Household Appliances                                         380
#                                                                                                                                Housewares & Specialties                                     153
#                                                                         Leisure Products                                       Leisure Products                                            1117
#                                                                         Textiles, Apparel & Luxury Goods                       Apparel, Accessories & Luxury Goods                         1646
#                                                                                                                                Footwear                                                     573
#                         Consumer Services                               Diversified Consumer Services                          Education Services                                           655
#                                                                                                                                Specialized Consumer Services                                345
#                                                                         Hotels, Restaurants & Leisure                          Casinos & Gaming                                            1088
#                                                                                                                                Copper                                                       147
#                                                                                                                                Diversified Metals & Mining                                  252
#                                                                                                                                Gold                                                         306
#                                                                                                                                Steel                                                       1483
#                                                                         Paper & Forest Products                                Forest Products                                              292
#                                                                                                                                Paper Products                                                80
# Real Estate             Equity Real Estate Investment Trusts (REITs)    Diversified REITs                                      Diversified REITs                                            603
#                                                                         Health Care REITs                                      Health Care REITs                                           1150
#                                                                         Hotel & Resort REITs                                   Hotel & Resort REITs                                         756
#                                                                         Industrial REITs                                       Industrial REITs                                             593
#                                                                         Office REITs                                           Office REITs                                                1391
#                                                                         Residential REITs                                      Multi-Family Residential REITs                              1073
#                                                                                                                                Single-Family Residential REITs                              155
#                                                                         Retail REITs                                           Retail REITs                                                2035
#                                                                         Specialized REITs                                      Data Center REITs                                            176
#                                                                                                                                Other Specialized REITs                                      475
#                                                                                                                                Self-Storage REITs                                           276
#                                                                                                                                Telecom Tower REITs                                          313
#                                                                                                                                Timber REITs                                                 429
#                         Financial Services                              Mortgage Real Estate Investment Trusts (REITs)         Mortgage REITs                                               407
#                         Real Estate Management & Development            Real Estate Management & Development                   Real Estate Development                                      143
#                                                                                                                                Real Estate Services                                         550
# Utilities               Utilities                                       Electric Utilities                                     Electric Utilities                                          2850
#                                                                         Gas Utilities                                          Gas Utilities                                               1273
#                                                                         Independent Power and Renewable Electricity Producers  Independent Power Producers & Energy Traders                 233
#                                                                                                                                Renewable Electricity                                        173
#                                                                         Multi-Utilities                                        Multi-Utilities                                             2404
#                                                                         Water Utilities                                        Water Utilities                                              905
# dtype: int64

# %% [markdown]
# Several Industry groups have been assigned to the wrong sector for some reason.

# %%
# Assign any improper GICS Sectors
sector_map = df_gics_info[['GICS Industry Group', 'GICS Sector']].drop_duplicates().set_index('GICS Industry Group').to_dict()['GICS Sector']
df['GICS Sector'] = df['GICS Industry Group'].map(sector_map)
with pd.option_context('display.max_rows', None):
	display(df.groupby(['GICS Sector', 'GICS Industry Group', 'GICS Industry', 'GICS Sub-Industry']).size())
# Out:
# GICS Sector             GICS Industry Group                             GICS Industry                                          GICS Sub-Industry
# Communication Services  Media & Entertainment                           Entertainment                                          Interactive Home Entertainment                               247
#                                                                                                                                Movies & Entertainment                                       805
#                                                                         Interactive Media & Services                           Interactive Media & Services                                 752
#                                                                         Media                                                  Advertising                                                  406
#                                                                                                                                Broadcasting                                                 491
#                                                                                                                                Cable & Satellite                                            293
#                                                                                                                                Publishing                                                   544
#                         Telecommunication Services                      Diversified Telecommunication Services                 Alternative Carriers                                         302
#                                                                                                                                Integrated Telecommunication Services                        679
#                                                                         Wireless Telecommunication Services                    Wireless Telecommunication Services                          291
# Consumer Discretionary  Automobiles & Components                        Automobile Components                                  Automotive Parts & Equipment                                1782
#                                                                                                                                Tires & Rubber                                               154
#                                                                         Automobiles                                            Automobile Manufacturers                                     429
#                                                                                                                                Motorcycle Manufacturers                                     153
#                         Consumer Discretionary Distribution & Retail    Broadline Retail                                       Broadline Retail                                             706
#                                                                         Distributors                                           Distributors                                                 402
#                                                                                                                                Specialty Chemicals                                         2843
#                                                                         Construction Materials                                 Construction Materials                                       402
#                                                                         Containers & Packaging                                 Metal, Glass & Plastic Containers                            788
#                                                                                                                                Paper & Plastic Packaging Products & Materials              1174
#                                                                         Metals & Mining                                        Aluminum                                                     277
#                                                                                                                                Copper                                                       147
#                                                                                                                                Diversified Metals & Mining                                  252
#                                                                                                                                Gold                                                         306
#                                                                                                                                Steel                                                       1483
#                                                                         Paper & Forest Products                                Forest Products                                              292
#                                                                                                                                Paper Products                                                80
# Real Estate             Equity Real Estate Investment Trusts (REITs)    Diversified REITs                                      Diversified REITs                                            603
#                                                                         Health Care REITs                                      Health Care REITs                                           1189
#                                                                         Hotel & Resort REITs                                   Hotel & Resort REITs                                         756
#                                                                         Industrial REITs                                       Industrial REITs                                             593
#                                                                         Office REITs                                           Office REITs                                                1451
#                                                                         Residential REITs                                      Multi-Family Residential REITs                              1073
#                                                                                                                                Single-Family Residential REITs                              155
#                                                                         Retail REITs                                           Retail REITs                                                2035
#                                                                         Specialized REITs                                      Data Center REITs                                            176
#                                                                                                                                Other Specialized REITs                                      475
#                                                                                                                                Self-Storage REITs                                           276
#                                                                                                                                Telecom Tower REITs                                          313
#                                                                                                                                Timber REITs                                                 429
#                         Real Estate Management & Development            Real Estate Management & Development                   Real Estate Development                                      143
#                                                                                                                                Real Estate Services                                         550
# Utilities               Utilities                                       Electric Utilities                                     Electric Utilities                                          2850
#                                                                         Gas Utilities                                          Gas Utilities                                               1273
#                                                                         Independent Power and Renewable Electricity Producers  Independent Power Producers & Energy Traders                 233
#                                                                                                                                Renewable Electricity                                        173
#                                                                         Multi-Utilities                                        Multi-Utilities                                             2404
#                                                                         Water Utilities                                        Water Utilities                                              905
# dtype: int64

# %% [markdown]
# #### Earnings

# %%
# Load Earnings
df_earn = pd.concat(
    [pd.read_csv(f'data/{cap}/earnings.csv') for cap in ['large', 'mid', 'small']])

df_earn['Earnings Date'] = df_earn['date'] + ' ' + df_earn['time']
df_earn.drop(columns=['date', 'time'], inplace=True)

df_earn['Earnings Date'] = pd.to_datetime(df_earn['Earnings Date'])
df_earn['asOfDate'] = pd.to_datetime(df_earn['Earnings Date'].dt.date)

# Merge earnings with financials
# SEC requires 40-45 days after the end of the quarter to file 10-Q 
# and earnings calls are typically before or same day as 10-Q filings,
# we'll use 50 days
df = pd.merge_asof(df.sort_values('asOfDate'), df_earn.sort_values(
    'asOfDate'), on='asOfDate', by='symbol', tolerance=pd.Timedelta(days=50), direction='forward')
# %xdel df_earn

print('Total Filings:', df.shape)
display(df.tail())
# Get the number of companies in each cap
print('\nCompany Counts:\n', df.groupby('cap')['symbol'].nunique())
# Get the number filings in each cap
print('\nFiling Counts:\n', df.groupby('cap').size())
# Out:
# Total Filings: (159841, 353)
#        symbol   asOfDate periodType currencyCode  AccountsPayable  \
# 159836   MDLZ 2023-12-31         3M          USD     8.321000e+09
# 159837   CRNC 2023-12-31         3M          USD     1.917900e+07
# 159838   META 2023-12-31         3M          USD     4.849000e+09
# 159839   LOPE 2023-12-31         3M          USD     1.767600e+07
# 159840    CRS 2023-12-31         3M          USD     3.134000e+08
#
#         AccountsReceivable  AccruedInterestReceivable  \
# 159836        3.634000e+09                        NaN
# 159837        5.869300e+07                        NaN
# 159838        1.616900e+10                        NaN
# 159839        7.881100e+07                        NaN
# 159840        5.084000e+08                        NaN
#
#         AccumulatedDepreciation  AdditionalPaidInCapital  \
# 159836            -7.996000e+09             3.221600e+10
# 159837                      NaN             1.064022e+09
# 159838            -3.313400e+10             7.325300e+10
# 159839            -1.704150e+08             3.225120e+08
# 159840                      NaN             3.279000e+08
#
#         AdjustedGeographySegmentData  ...             GICS Sector  \
# 159836                           NaN  ...        Consumer Staples
# 159837                           NaN  ...  Information Technology
# 159838                           NaN  ...  Communication Services
# 159839                           NaN  ...  Consumer Discretionary
# 159840                           NaN  ...               Materials
#
#                    GICS Sub-Industry  GICS Sector ID  GICS Industry Group ID  \
# 159836        Packaged Foods & Meats              30                    3020
# 159837          Application Software              45                    4510
# 159838  Interactive Media & Services              50                    5020
# 159839            Education Services              25                    2530
# 159840                         Steel              15                    1510
#
#              GICS Industry Group  GICS Industry ID  \
# 159836  Food, Beverage & Tobacco          302020.0
# 159837       Software & Services          451030.0
# 159838     Media & Entertainment          502030.0
# 159839         Consumer Services          253020.0
# 159840                 Materials          151040.0
#
#                         GICS Industry  GICS Sub-Industry ID  \
# 159836                  Food Products            30202030.0
# 159837                       Software            45103010.0
# 159838   Interactive Media & Services            50203010.0
# 159839  Diversified Consumer Services            25302010.0
# 159840                Metals & Mining            15104050.0
#
#                          title       Earnings Date
# 159836  Mondelez International 2024-01-30 16:05:00
# 159837                 Cerence 2024-02-06 07:00:00
# 159838          Meta Platforms 2024-02-01 16:05:00
# 159839  Grand Canyon Education 2024-02-13 16:05:00
# 159840          Carpenter Tech 2024-01-25 08:00:00
#
# [5 rows x 353 columns]
# Company Counts:
#  cap
# large    503
# mid      401
# small    602
# Name: symbol, dtype: int64
#
# Filing Counts:
#  cap
# large    60852
# mid      40274
# small    58715
# dtype: int64

# %% [markdown]
# ### Categorical Columns

# %%
cat_cols = ['symbol', 'cap', 'GICS Sector ID', 'GICS Sector', 'GICS Industry Group ID', 'GICS Industry Group', 'GICS Industry ID', 'GICS Industry', 'GICS Sub-Industry ID', 'GICS Sub-Industry']
df[cat_cols] = df[cat_cols].apply(lambda x: x.astype('category'))

# %% [markdown]
# ### Clean

# %%
import json

# Drop earnings date outside of the date range
df = df[(df['Earnings Date'] >= DATE_START_OFFSET) &
        (df['Earnings Date'] <= DATE_END)]
print('Filings in Range:', df.shape)

# Remove filings where the company name is not in the company names list,
# tickers may change hands between companies. Known names for each company
# was collected from SEC filings, we'll also compare with the title of the
# company from the earnings data in case the company's common name is not
# the same as the official name registered with the SEC
companies = {}
for cap in ['large', 'mid', 'small']:
    with open(f'data/{cap}/company_names.json') as f:
        companies.update(json.load(f))


def drop_row(row):
    ticker = row['symbol']
    company_list = companies.get(ticker, [])

    def fmt(s: str) -> str:
        return s.lower().replace('.', '').replace(',', '').replace('\'', '').replace('-', ' ').replace(' ', '')
    # Ensure the first several chars of the company name is in the list
    title: str = fmt(row['title'])
    security = None
    if type(row['Security']) != float:
        security = fmt(row['Security'])
    length = int(max(len(title)/2, 3))
    if not any(fmt(i).startswith(title[:length]) for i in company_list) and \
            not (True if not security else title.startswith(security[:length])):
        return True
    else:
        return False

df = df[~df.apply(drop_row, axis=1)]

# %xdel companies

print('Filings with Correct Name:', df.shape)
# Get the number of companies in each cap
print('\nCompany Counts:\n', df.groupby(
    'cap', observed=True)['symbol'].nunique())
# Get the number of companies in each cap by sector
print('\nCompany Counts by cap and sector:\n',
      df.groupby(['cap', 'GICS Sector'], observed=True)['symbol'].nunique())
# Get the number of filings in each cap by sector
print('\nFiling Counts by cap and sector:\n',
      df.groupby(['cap', 'GICS Sector'], observed=True).size())
# Out:
# Filings in Range: (53434, 353)
# Filings with Correct Name: (53151, 353)
#
# Company Counts:
#  cap
# large    498
# mid      397
# small    599
# Name: symbol, dtype: int64
#
# Company Counts by cap and sector:
#  cap    GICS Sector
# large  Communication Services     22
#        Consumer Discretionary     53
#        Consumer Staples           37
#        Energy                     22
#        Financials                 70
#        Health Care                64
#        Industrials                78
#        Information Technology     64
#        Materials                  27
#        Real Estate                31
#        Utilities                  30
# mid    Communication Services      8
#        Consumer Discretionary     65
#        Consumer Staples           18
#        Energy                     20
#        Financials                 64
#        Health Care                35
#        Industrials                73
#        Information Technology     41
#        Materials                  27
#        Real Estate                30
#        Utilities                  16
# small  Communication Services     23
#        Consumer Discretionary     84
#        Consumer Staples           29
#        Energy                     29
#        Financials                117
#        Health Care                68
#        Industrials                95
#        Information Technology     63
#        Materials                  31
#        Real Estate                50
#        Utilities                  10
# Name: symbol, dtype: int64
#
# Filing Counts by cap and sector:
#  cap    GICS Sector
# large  Communication Services     825
#        Consumer Discretionary    2072
#        Consumer Staples          1441
#        Energy                     826
#        Financials                2791
#        Health Care               2445
#        Industrials               2922
#        Information Technology    2617
#        Materials                  969
#        Real Estate               1187
#        Utilities                 1075
# mid    Communication Services     223
#        Consumer Discretionary    2328
#        Consumer Staples           569
#        Energy                     515
#        Financials                2499
#        Health Care               1049
#        Industrials               2573
#        Information Technology    1490
#        Materials                  995
#        Real Estate               1062
#        Utilities                  569
# small  Communication Services     771
#        Consumer Discretionary    2882
#        Consumer Staples           980
#        Energy                     943
#        Financials                4233
#        Health Care               1934
#        Industrials               3322
#        Information Technology    2107
#        Materials                 1019
#        Real Estate               1574
#        Utilities                  344
# dtype: int64

# %% [markdown]
# ### Derive Features
#
# #### Earnings - BMO or AMC (Before Market Open or After Market Clore)

# %%
# Determine BMO or AMC
# We can assume any earnings date after 4pm is AMC, and before is BMO
def bmo_amc(date: pd.Timestamp) -> str:
    if date.hour >= 16:
        return 'AMC'
    else:
        return 'BMO'


df['BMO/AMC'] = df['Earnings Date'].apply(bmo_amc)
df['BMO/AMC'] = df['BMO/AMC'].astype('category')
df.tail(3)
# Out:
#        symbol   asOfDate periodType currencyCode  AccountsPayable  \
# 159838   META 2023-12-31         3M          USD     4.849000e+09
# 159839   LOPE 2023-12-31         3M          USD     1.767600e+07
# 159840    CRS 2023-12-31         3M          USD     3.134000e+08
#
#         AccountsReceivable  AccruedInterestReceivable  \
# 159838        1.616900e+10                        NaN
# 159839        7.881100e+07                        NaN
# 159840        5.084000e+08                        NaN
#
#         AccumulatedDepreciation  AdditionalPaidInCapital  \
# 159838            -3.313400e+10             7.325300e+10
# 159839            -1.704150e+08             3.225120e+08
# 159840                      NaN             3.279000e+08
#
#         AdjustedGeographySegmentData  ...             GICS Sub-Industry  \
# 159838                           NaN  ...  Interactive Media & Services
# 159839                           NaN  ...            Education Services
# 159840                           NaN  ...                         Steel
#
#         GICS Sector ID  GICS Industry Group ID    GICS Industry Group  \
# 159838              50                    5020  Media & Entertainment
# 159839              25                    2530      Consumer Services
# 159840              15                    1510              Materials
#
#         GICS Industry ID                  GICS Industry  GICS Sub-Industry ID  \
# 159838          502030.0   Interactive Media & Services            50203010.0
# 159839          253020.0  Diversified Consumer Services            25302010.0
# 159840          151040.0                Metals & Mining            15104050.0
#
#                          title       Earnings Date  BMO/AMC
# 159838          Meta Platforms 2024-02-01 16:05:00      AMC
# 159839  Grand Canyon Education 2024-02-13 16:05:00      AMC
# 159840          Carpenter Tech 2024-01-25 08:00:00      BMO
#
# [3 rows x 354 columns]

# %% [markdown]
# #### Earnings - Effect on Stock Date

# %%
from pandas.tseries.holiday import nearest_workday, AbstractHolidayCalendar, Holiday, USMartinLutherKingJr, USPresidentsDay, GoodFriday, USMemorialDay, USLaborDay, USThanksgivingDay
from pandas.tseries.offsets import CustomBusinessDay


class USStockMarketCalendar(AbstractHolidayCalendar):
    # Holidays for US Stock Market

    rules = [
        # New Year's Day
        Holiday('New Years', month=1, day=1, observance=nearest_workday),
        # Martin Luther King Jr. Day (3rd Monday in January)
        USMartinLutherKingJr,
        # Presidents' Day (3rd Monday in February)
        USPresidentsDay,
        # Good Friday (Friday before Easter Sunday)
        GoodFriday,
        # Memorial Day (last Monday in May)
        USMemorialDay,
        # Independence Day
        Holiday('Independence Day', month=7,
                day=4, observance=nearest_workday),
        # Labor Day (1st Monday in September)
        USLaborDay,
        # Thanksgiving Day (4th Thursday in November)
        USThanksgivingDay,
        # Christmas Day
        Holiday('Christmas', month=12, day=25, observance=nearest_workday),
        # Juneteenth (June 19th, observed starting 2022)
        Holiday('Juneteenth', month=6, day=19,
                start_date='2022-06-18', observance=nearest_workday),
    ]


# Create a custom business day offset using the custom calendar
bday = CustomBusinessDay(calendar=USStockMarketCalendar())


# Get the date the earnings call will affect the stock price
# If the earnings call is BMO, the stock price will be affected the same day (assuming earnings was on a weekday)
# If the earnings call is AMC, the stock price will be affected the next business day
def stock_effect_date(row: pd.Series):
    if row['BMO/AMC'] == 'BMO' and row['Earnings Date'].dayofweek < 5:
        return row['Earnings Date'].date()
    else:
        return (row['Earnings Date'] + bday).date()


df['Stock Affect Date'] = df.apply(stock_effect_date, axis=1)
display(df.tail(3))
# Out:
#        symbol   asOfDate periodType currencyCode  AccountsPayable  \
# 159838   META 2023-12-31         3M          USD     4.849000e+09
# 159839   LOPE 2023-12-31         3M          USD     1.767600e+07
# 159840    CRS 2023-12-31         3M          USD     3.134000e+08
#
#         AccountsReceivable  AccruedInterestReceivable  \
# 159838        1.616900e+10                        NaN
# 159839        7.881100e+07                        NaN
# 159840        5.084000e+08                        NaN
#
#         AccumulatedDepreciation  AdditionalPaidInCapital  \
# 159838            -3.313400e+10             7.325300e+10
# 159839            -1.704150e+08             3.225120e+08
# 159840                      NaN             3.279000e+08
#
#         AdjustedGeographySegmentData  ...  GICS Sector ID  \
# 159838                           NaN  ...              50
# 159839                           NaN  ...              25
# 159840                           NaN  ...              15
#
#         GICS Industry Group ID    GICS Industry Group  GICS Industry ID  \
# 159838                    5020  Media & Entertainment          502030.0
# 159839                    2530      Consumer Services          253020.0
# 159840                    1510              Materials          151040.0
#
#                         GICS Industry  GICS Sub-Industry ID  \
# 159838   Interactive Media & Services            50203010.0
# 159839  Diversified Consumer Services            25302010.0
# 159840                Metals & Mining            15104050.0
#
#                          title       Earnings Date  BMO/AMC  Stock Affect Date
# 159838          Meta Platforms 2024-02-01 16:05:00      AMC         2024-02-02
# 159839  Grand Canyon Education 2024-02-13 16:05:00      AMC         2024-02-14
# 159840          Carpenter Tech 2024-01-25 08:00:00      BMO         2024-01-25
#
# [3 rows x 355 columns]

# %% [markdown]
# #### Ratios

# %%
def column_nulls(df: pd.DataFrame):
    # Find columns within financials
    income_cols = ['revenue', 'sales', 'goodssold',
                   'profit', 'expense', 'income', 'ebit', 'eps', 'minority', 'dividend', 'research', 'r&d', 'provision']
    balance_cols = ['asset', 'liabilit', 'equity', 'debt', 'inventory', 'account',
                    'minority', 'share', 'current', 'accrued', 'development' 'reserve']
    cash_cols = ['flow', 'cash', 'capex']

    income_nulls = {}
    balance_nulls = {}
    cash_nulls = {}
    for col in df.columns:
        # Check for income-related columns
        if any(keyword in col.lower() for keyword in income_cols):
            null_count = df[col].isnull().sum()
            income_nulls[col] = null_count

        # Check for balance-related columns
        if any(keyword in col.lower() for keyword in balance_cols):
            null_count = df[col].isnull().sum()
            balance_nulls[col] = null_count

        # Check for cash-related columns
        if any(keyword in col.lower() for keyword in cash_cols):
            null_count = df[col].isnull().sum()
            cash_nulls[col] = null_count

    return income_nulls, balance_nulls, cash_nulls


income_nulls, balance_nulls, cash_nulls = column_nulls(df)
[display(pd.Series(x).sort_index().sort_values().head(60))
 for x in [income_nulls, balance_nulls, cash_nulls]]

# %reset_selective -f income_nulls balance_nulls cash_nulls
# Out:
# NetIncomeCommonStockholders                               42
# PretaxIncome                                              42
# OperatingRevenue                                          42
# NormalizedIncome                                          42
# NetIncomeIncludingNoncontrollingInterests                 42
# NetIncomeFromContinuingOperationNetMinorityInterest       42
# NetIncomeFromContinuingAndDiscontinuedOperation           42
# NetIncomeContinuousOperations                             42
# NetIncome                                                 42
# TotalRevenue                                              42
# TotalLiabilitiesNetMinorityInterest                       74
# TotalEquityGrossMinorityInterest                          74
# NetIncomeFromContinuingOperations                        875
# BasicEPS                                                 888
# DilutedEPS                                               888
# TaxProvision                                            1780
# NetInterestIncome                                       1953
# PayablesAndAccruedExpenses                              2164
# TotalExpenses                                           5242
# InterestExpense                                         5400
# EBIT                                                    5443
# NetNonOperatingInterestIncomeExpense                    7161
# OperatingIncome                                         7432
# OperatingExpense                                        7437
# EBITDA                                                  7501
# NormalizedEBITDA                                        7501
# TotalNonCurrentLiabilitiesNetMinorityInterest           7539
# ReconciledCostOfRevenue                                 7935
# GrossProfit                                             7935
# CostOfRevenue                                           7942
# ChangeInPayablesAndAccruedExpense                       8245
# OtherIncomeExpense                                     10074
# InterestExpenseNonOperating                            10601
# DeferredIncomeTax                                      13451
# CurrentAccruedExpenses                                 14086
# TotalOperatingIncomeAsReported                         14602
# CashDividendsPaid                                      15288
# OtherNonOperatingIncomeExpenses                        19228
# SpecialIncomeCharges                                   19549
# CommonStockDividendPaid                                19606
# InterestIncome                                         25261
# GeneralAndAdministrativeExpense                        25903
# DepreciationAndAmortizationInIncomeStatement           27840
# DepreciationAmortizationDepletionIncomeStatement       27899
# MinorityInterest                                       29918
# MinorityInterests                                      30824
# InterestIncomeNonOperating                             30855
# IncomeTaxPaidSupplementalData                          31333
# CurrentDeferredRevenue                                 31340
# ChangeInAccruedExpense                                 33189
# IncomeTaxPayable                                       35777
# OtherOperatingExpenses                                 37693
# ResearchAndDevelopment                                 39144
# SellingAndMarketingExpense                             39866
# ChangeInIncomeTaxPayable                               41458
# ProvisionandWriteOffofAssets                           41548
# AmortizationOfIntangiblesIncomeStatement               41986
# NonCurrentDeferredRevenue                              43018
# OtherunderPreferredStockDividend                       43665
# NetIncomeDiscontinuousOperations                       44333
# dtype: int64
# NetIncomeFromContinuingOperationNetMinorityInterest       42
# TotalLiabilitiesNetMinorityInterest                       74
# TotalEquityGrossMinorityInterest                          74
# TotalAssets                                               74
# StockholdersEquity                                        74
# NetTangibleAssets                                         74
# CommonStockEquity                                         74
# ShareIssued                                               80
# OrdinarySharesNumber                                      80
# BasicAverageShares                                       882
# DilutedAverageShares                                     882
# PayablesAndAccruedExpenses                              2164
# TotalDebt                                               2778
# LongTermDebtAndCapitalLeaseObligation                   3394
# AccountsReceivable                                      3608
# NetIssuancePaymentsOfDebt                               4608
# AccountsPayable                                         5824
# LongTermDebt                                            6306
# GoodwillAndOtherIntangibleAssets                        6528
# NetLongTermDebtIssuance                                 7031
# CurrentAssets                                           7539
# TotalNonCurrentLiabilitiesNetMinorityInterest           7539
# TotalNonCurrentAssets                                   7539
# CurrentLiabilities                                      7548
# RepaymentOfDebt                                         7731
# ChangeInPayablesAndAccruedExpense                       8245
# LongTermDebtPayments                                    9161
# OtherNonCurrentAssets                                  10001
# OtherNonCurrentLiabilities                             12379
# NetDebt                                                12995
# OtherIntangibleAssets                                  13103
# CurrentDebtAndCapitalLeaseObligation                   13477
# OtherEquityAdjustments                                 13956
# CurrentAccruedExpenses                                 14086
# IssuanceOfDebt                                         14452
# NonCurrentDeferredLiabilities                          16104
# ChangeInAccountPayable                                 17272
# OtherCurrentAssets                                     17460
# LongTermDebtIssuance                                   17601
# ChangesInAccountReceivables                            18192
# CurrentDebt                                            18456
# Inventory                                              19716
# NonCurrentDeferredTaxesLiabilities                     21452
# PrepaidAssets                                          22191
# TreasurySharesNumber                                   24839
# ChangeInInventory                                      24868
# NetShortTermDebtIssuance                               27115
# GrossAccountsReceivable                                28277
# NonCurrentDeferredAssets                               28578
# AllowanceForDoubtfulAccountsReceivable                 28950
# MinorityInterest                                       29918
# CurrentDeferredLiabilities                             29952
# ChangeInOtherCurrentAssets                             30146
# MinorityInterests                                      30824
# CurrentDeferredRevenue                                 31340
# OtherCurrentLiabilities                                31498
# ChangeInPrepaidAssets                                  31851
# NonCurrentDeferredTaxesAssets                          32574
# ChangeInAccruedExpense                                 33189
# ChangeInOtherCurrentLiabilities                        33734
# dtype: int64
# FreeCashFlow                                       65
# EndCashPosition                                    71
# FinancingCashFlow                                  75
# BeginningCashPosition                              84
# ChangeInCashSupplementalAsReported                 90
# InvestingCashFlow                                  94
# OperatingCashFlow                                 117
# CashAndCashEquivalents                            173
# ChangesInCash                                     176
# CashFlowFromContinuingFinancingActivities         208
# CashFlowFromContinuingInvestingActivities         227
# CashFlowFromContinuingOperatingActivities         924
# CashCashEquivalentsAndShortTermInvestments       5313
# OtherNonCashItems                                8449
# CashDividendsPaid                               15288
# AmortizationCashFlow                            40601
# RestrictedCash                                  42091
# CashFinancial                                   46306
# CashFromDiscontinuedOperatingActivities         49569
# CashEquivalents                                 50385
# CashFromDiscontinuedInvestingActivities         50461
# CashFromDiscontinuedFinancingActivities         51694
# OtherCashAdjustmentOutsideChangeinCash          52140
# CashFlowFromDiscontinuedOperation               52469
# OtherCashAdjustmentInsideChangeinCash           52937
# ClassesofCashPayments                           53094
# ClassesofCashReceiptsfromOperatingActivities    53094
# CashFlowsfromusedinOperatingActivitiesDirect    53094
# OtherCashReceiptsfromOperatingActivities        53094
# OtherCashPaymentsfromOperatingActivities        53099
# dtype: int64

# %%
# Columns with no null values
print('Columns with no null values:', len(
    df.columns[df.notnull().all()]), df.columns[df.notnull().all()])
# Out:
# Columns with no null values: 17 Index(['symbol', 'asOfDate', 'periodType', 'currencyCode', 'cap',
#        'GICS Sector', 'GICS Sub-Industry', 'GICS Sector ID',
#        'GICS Industry Group ID', 'GICS Industry Group', 'GICS Industry ID',
#        'GICS Industry', 'GICS Sub-Industry ID', 'title', 'Earnings Date',
#        'BMO/AMC', 'Stock Affect Date'],
#       dtype='object')

# %%
cols = ['TotalRevenue', 'OperatingRevenue', 'NetIncome', 'BasicEPS', 'DilutedEPS', 'EBITDA', 'EBIT']

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print('Nulls:\n', df.dropna(subset=cols + ['CurrentLiabilities']).isnull().sum().sort_values())
# Out:
# Nulls:
#  symbol                                                              0
# PretaxIncome                                                        0
# OperatingRevenue                                                    0
# OperatingIncome                                                     0
# NormalizedIncome                                                    0
# NormalizedEBITDA                                                    0
# NetTangibleAssets                                                   0
# NetIncomeIncludingNoncontrollingInterests                           0
# NetIncomeFromContinuingOperationNetMinorityInterest                 0
# NetIncomeFromContinuingAndDiscontinuedOperation                     0
# NetIncomeContinuousOperations                                       0
# NetIncomeCommonStockholders                                         0
# NetIncome                                                           0
# BMO/AMC                                                             0
# EBITDA                                                              0
# EBIT                                                                0
# DilutedNIAvailtoComStockholders                                     0
# DilutedEPS                                                          0
# DilutedAverageShares                                                0
# CurrentLiabilities                                                  0
# StockholdersEquity                                                  0
# CurrentAssets                                                       0
# TangibleBookValue                                                   0
# TaxRateForCalcs                                                     0
# Earnings Date                                                       0
# title                                                               0
# GICS Sub-Industry ID                                                0
# GICS Industry                                                       0
# GICS Industry ID                                                    0
# GICS Industry Group                                                 0
# GICS Industry Group ID                                              0
# GICS Sector ID                                                      0
# GICS Sub-Industry                                                   0
# GICS Sector                                                         0
# cap                                                                 0
# WorkingCapital                                                      0
# TotalRevenue                                                        0
# TotalNonCurrentLiabilitiesNetMinorityInterest                       0
# TotalNonCurrentAssets                                               0
# TotalLiabilitiesNetMinorityInterest                                 0
# TotalEquityGrossMinorityInterest                                    0
# TotalCapitalization                                                 0
# TotalAssets                                                         0
# TaxEffectOfUnusualItems                                             0
# CommonStockEquity                                                   0
# Stock Affect Date                                                   0
# BasicAverageShares                                                  0
# BasicEPS                                                            0
# currencyCode                                                        0
# periodType                                                          0
# asOfDate                                                            0
# TotalExpenses                                                       2
# ShareIssued                                                         2
# OrdinarySharesNumber                                                2
# FreeCashFlow                                                       17
# OperatingCashFlow                                                  17
# EndCashPosition                                                    20
# InvestedCapital                                                    20
# FinancingCashFlow                                                  22
# InvestingCashFlow                                                  22
# CashFlowFromContinuingInvestingActivities                          24
# CashFlowFromContinuingFinancingActivities                          24
# PayablesAndAccruedExpenses                                         31
# BeginningCashPosition                                              32
# ChangeInCashSupplementalAsReported                                 40
# CashCashEquivalentsAndShortTermInvestments                         40
# OperatingExpense                                                   90
# CashAndCashEquivalents                                             98
# ChangesInCash                                                     124
# ReconciledDepreciation                                            299
# CashFlowFromContinuingOperatingActivities                         315
# CapitalStock                                                      322
# CommonStock                                                       324
# NetIncomeFromContinuingOperations                                 348
# GrossProfit                                                       417
# ReconciledCostOfRevenue                                           417
# CostOfRevenue                                                     424
# DepreciationAmortizationDepletion                                 445
# ChangeInWorkingCapital                                            470
# RetainedEarnings                                                  480
# Receivables                                                       755
# AccountsReceivable                                               1529
# Payables                                                         1572
# TaxProvision                                                     1579
# NetInterestIncome                                                1675
# NetNonOperatingInterestIncomeExpense                             1685
# CapitalExpenditure                                               1694
# AccountsPayable                                                  1770
# NetPPE                                                           1911
# OtherNonCurrentAssets                                            2426
# TotalDebt                                                        2462
# DepreciationAndAmortization                                      2466
# SellingGeneralAndAdministration                                  2666
# LongTermDebtAndCapitalLeaseObligation                            2978
# AdditionalPaidInCapital                                          3538
# GainsLossesNotAffectingRetainedEarnings                          3995
# NetIssuancePaymentsOfDebt                                        4004
# OtherIncomeExpense                                               4246
# OtherNonCurrentLiabilities                                       4762
# InterestExpense                                                  5068
# InterestExpenseNonOperating                                      5074
# StockBasedCompensation                                           5124
# GoodwillAndOtherIntangibleAssets                                 5267
# ChangeInPayablesAndAccruedExpense                                5295
# LongTermDebt                                                     5662
# NetLongTermDebtIssuance                                          5674
# RepaymentOfDebt                                                  6167
# ChangeInReceivables                                              6299
# NetOtherFinancingCharges                                         6426
# OtherNonCashItems                                                6766
# TotalOperatingIncomeAsReported                                   6918
# NetCommonStockIssuance                                           7387
# LongTermDebtPayments                                             7476
# CurrentAccruedExpenses                                           8234
# GrossPPE                                                         8391
# Goodwill                                                         8545
# CurrentDebtAndCapitalLeaseObligation                             9188
# OtherEquityAdjustments                                           9530
# DeferredTax                                                      9681
# DeferredIncomeTax                                                9681
# OtherCurrentAssets                                               9739
# NonCurrentDeferredLiabilities                                    9853
# NetDebt                                                         10297
# OtherIntangibleAssets                                           10309
# ChangeInOtherWorkingCapital                                     11394
# OtherNonOperatingIncomeExpenses                                 11824
# IssuanceOfDebt                                                  11906
# RepurchaseOfCapitalStock                                        11949
# Inventory                                                       11986
# TotalUnusualItems                                               11991
# TotalUnusualItemsExcludingGoodwill                              12004
# ChangeInPayable                                                 12070
# CommonStockPayments                                             12303
# ChangeInAccountPayable                                          12469
# NetPPEPurchaseAndSale                                           12540
# OperatingGainsLosses                                            13150
# CurrentDebt                                                     14081
# ChangesInAccountReceivables                                     14328
# CashDividendsPaid                                               14648
# LongTermDebtIssuance                                            14815
# NonCurrentDeferredTaxesLiabilities                              14839
# SpecialIncomeCharges                                            15312
# EffectOfExchangeRateChanges                                     15478
# PrepaidAssets                                                   15939
# NetBusinessPurchaseAndSale                                      16016
# Security                                                        16352
# AccumulatedDepreciation                                         16735
# ChangeInInventory                                               17032
# PurchaseOfPPE                                                   17319
# NetOtherInvestingChanges                                        17486
# CommonStockDividendPaid                                         17982
# PurchaseOfBusiness                                              18958
# OtherProperties                                                 19862
# TreasuryStock                                                   20435
# GrossAccountsReceivable                                         20602
# NonCurrentDeferredAssets                                        20734
# PreferredStock                                                  20874
# ProceedsFromStockOptionExercised                                21046
# AllowanceForDoubtfulAccountsReceivable                          21210
# TotalTaxPayable                                                 21666
# TreasurySharesNumber                                            21742
# NetInvestmentPurchaseAndSale                                    21784
# FinishedGoods                                                   22150
# CurrentDeferredLiabilities                                      22183
# NetShortTermDebtIssuance                                        22569
# InterestIncome                                                  22938
# InterestIncomeNonOperating                                      22974
# DepreciationAmortizationDepletionIncomeStatement                23196
# CurrentDeferredRevenue                                          23534
# OtherCurrentLiabilities                                         23644
# DepreciationAndAmortizationInIncomeStatement                    23658
# RawMaterials                                                    23975
# MinorityInterest                                                24108
# GeneralAndAdministrativeExpense                                 24250
# CapitalLeaseObligations                                         24498
# ChangeInPrepaidAssets                                           24620
# NonCurrentDeferredTaxesAssets                                   24638
# OtherGandA                                                      24915
# MinorityInterests                                               24940
# CapitalExpenditureReported                                      25220
# LongTermCapitalLeaseObligation                                  25366
# PurchaseOfInvestment                                            25566
# InvestmentsAndAdvances                                          25685
# SaleOfInvestment                                                25940
# InterestPaidSupplementalData                                    26279
# ChangeInOtherCurrentAssets                                      26388
# ChangeInAccruedExpense                                          26581
# IncomeTaxPaidSupplementalData                                   27603
# PensionandOtherPostRetirementBenefitPlansCurrent                27810
# RestructuringAndMergernAcquisition                              28270
# MachineryFurnitureEquipment                                     28381
# OtherCurrentBorrowings                                          28516
# ChangeInOtherCurrentLiabilities                                 28532
# IncomeTaxPayable                                                28908
# WorkInProcess                                                   28971
# Properties                                                      29017
# Depreciation                                                    30126
# IssuanceOfCapitalStock                                          30552
# CurrentCapitalLeaseObligation                                   30572
# EmployeeBenefits                                                30663
# GainOnSaleOfSecurity                                            30763
# CommonStockIssuance                                             30795
# OtherShortTermInvestments                                       30861
# OtherReceivables                                                30971
# SaleOfPPE                                                       31032
# ResearchAndDevelopment                                          31063
# AssetImpairmentCharge                                           31281
# OtherOperatingExpenses                                          31503
# ShortTermDebtIssuance                                           31968
# ShortTermDebtPayments                                           32434
# LandAndImprovements                                             32542
# BuildingsAndImprovements                                        33055
# ConstructionInProgress                                          33103
# NonCurrentPensionAndOtherPostretirementBenefitPlans             33215
# EarningsLossesFromEquityInvestments                             33421
# ProvisionandWriteOffofAssets                                    33429
# RestrictedCash                                                  34056
# ChangeInTaxPayable                                              34257
# ChangeInIncomeTaxPayable                                        34261
# GainLossOnInvestmentSecurities                                  34346
# EarningsFromEquityInterest                                      34612
# LongTermEquityInvestment                                        34750
# AmortizationOfIntangibles                                       34766
# AmortizationCashFlow                                            34767
# GainLossOnSaleOfPPE                                             34809
# NonCurrentDeferredRevenue                                       35339
# SellingAndMarketingExpense                                      35419
# SaleOfBusiness                                                  35748
# TotalOtherFinanceCost                                           35817
# TaxesReceivable                                                 35820
# CurrentDeferredAssets                                           36007
# InterestPayable                                                 36029
# ImpairmentOfCapitalAssets                                       36539
# AmortizationOfIntangiblesIncomeStatement                        36607
# Amortization                                                    36607
# OtherSpecialCharges                                             36867
# NetIncomeDiscontinuousOperations                                37036
# GainOnSaleOfPPE                                                 37292
# OtherunderPreferredStockDividend                                37514
# Leases                                                          37800
# CurrentDeferredTaxesAssets                                      37818
# TradeandOtherPayablesNonCurrent                                 37829
# AssetsHeldForSaleCurrent                                        37952
# PensionAndEmployeeBenefitExpense                                38180
# LineOfCredit                                                    38508
# DividendsPayable                                                38669
# OtherPayable                                                    38909
# GainLossOnSaleOfBusiness                                        39221
# ExcessTaxBenefitFromStockBasedCompensation                      39296
# InvestmentinFinancialAssets                                     39367
# NetIntangiblesPurchaseAndSale                                   39487
# WriteOff                                                        39513
# CurrentProvisions                                               39646
# LongTermProvisions                                              39693
# PurchaseOfIntangibles                                           39803
# InventoriesAdjustmentsAllowances                                40139
# PreferredSecuritiesOutsideStockEquity                           40208
# SalariesAndWages                                                40369
# DividendReceivedCFO                                             40454
# GainOnSaleOfBusiness                                            40576
# AverageDilutionEarnings                                         40599
# NonCurrentAccountsReceivable                                    40601
# NetForeignCurrencyExchangeGainLoss                              40625
# OtherInvestments                                                40805
# EarningsFromEquityInterestNetOfTax                              40862
# NonCurrentPrepaidAssets                                         41145
# InvestmentProperties                                            41205
# AvailableForSaleSecurities                                      41255
# AmortizationOfSecurities                                        41312
# OtherInventories                                                41317
# NetInvestmentPropertiesPurchaseAndSale                          41342
# ReceivablesAdjustmentsAllowances                                41344
# PreferredStockDividends                                         41355
# RentExpenseSupplemental                                         41395
# CashFinancial                                                   41467
# DerivativeProductLiabilities                                    41540
# CashFromDiscontinuedOperatingActivities                         41541
# PurchaseOfInvestmentProperties                                  41566
# OtherTaxes                                                      41734
# PreferredStockEquity                                            41754
# InvestmentsinAssociatesatCost                                   41756
# PreferredSharesNumber                                           42029
# HedgingAssetsCurrent                                            42121
# CurrentNotesPayable                                             42129
# DividendsReceivedCFI                                            42134
# DepreciationIncomeStatement                                     42199
# FinancialAssets                                                 42232
# DefinedPensionBenefit                                           42276
# OtherEquityInterest                                             42330
# CashFromDiscontinuedInvestingActivities                         42360
# SaleOfInvestmentProperties                                      42470
# NonCurrentAccruedExpenses                                       42551
# CashEquivalents                                                 42602
# NonCurrentNoteReceivables                                       42826
# NotesReceivable                                                 42833
# CommercialPaper                                                 42837
# InvestmentsinJointVenturesatCost                                42869
# UnrealizedGainLossOnInvestmentSecurities                        42943
# PreferredStockDividendPaid                                      42980
# ChangeInInterestPayable                                         43071
# CurrentDeferredTaxesLiabilities                                 43203
# LiabilitiesHeldforSaleNonCurrent                                43203
# RentAndLandingFees                                              43276
# DuefromRelatedPartiesCurrent                                    43299
# LoansReceivable                                                 43361
# DuetoRelatedPartiesCurrent                                      43436
# CashFromDiscontinuedFinancingActivities                         43519
# NetPreferredStockIssuance                                       43596
# ProvisionForDoubtfulAccounts                                    43814
# OtherCapitalStock                                               43830
# ForeignCurrencyTranslationAdjustments                           43940
# MinimumPensionLiabilities                                       43949
# InvestmentsInOtherVenturesUnderEquityMethod                     43959
# OtherCashAdjustmentOutsideChangeinCash                          44030
# HeldToMaturitySecurities                                        44101
# PreferredStockPayments                                          44144
# InsuranceAndClaims                                              44197
# PreferredStockIssuance                                          44227
# CashFlowFromDiscontinuedOperation                               44257
# AccruedInterestReceivable                                       44390
# InvestmentsinSubsidiariesatCost                                 44446
# SaleOfIntangibles                                               44492
# ExciseTaxes                                                     44548
# UnrealizedGainLoss                                              44564
# DuetoRelatedPartiesNonCurrent                                   44581
# Depletion                                                       44597
# TradingSecurities                                               44601
# InterestReceivedCFI                                             44633
# TaxesRefundPaid                                                 44638
# NetIncomeExtraordinary                                          44654
# InterestPaidCFF                                                 44671
# DuefromRelatedPartiesNonCurrent                                 44681
# FinancialAssetsDesignatedasFairValueThroughProfitorLossTotal    44712
# OtherCashAdjustmentInsideChangeinCash                           44718
# SecuritiesAmortization                                          44748
# DomesticSales                                                   44752
# ForeignSales                                                    44760
# NetIncomeFromTaxLossCarryforward                                44804
# InterestPaidCFO                                                 44813
# RestrictedCommonStock                                           44821
# DividendPaidCFO                                                 44830
# ChangeInDividendPayable                                         44836
# InterestReceivedCFO                                             44850
# DepletionIncomeStatement                                        44852
# AdjustedGeographySegmentData                                    44860
# TotalPartnershipCapital                                         44870
# GeneralPartnershipCapital                                       44871
# LimitedPartnershipCapital                                       44874
# CashFlowsfromusedinOperatingActivitiesDirect                    44879
# OtherCashPaymentsfromOperatingActivities                        44879
# FixedAssetsRevaluationReserve                                   44879
# OtherCashReceiptsfromOperatingActivities                        44879
# PaymentsonBehalfofEmployees                                     44879
# ClassesofCashReceiptsfromOperatingActivities                    44879
# ClassesofCashPayments                                           44879
# dtype: int64

# %% [markdown]
# ##### Liquidity Ratios

# %%
cols += ['Current Ratio', 'Quick Ratio']

# Current Ratio
required_cols = ['Current Ratio']
df['Current Ratio'] = df['CurrentAssets'] / df['CurrentLiabilities']

# Acid Test Ratio
# Not all companies report Inventory
df['Quick Ratio'] = (df['CurrentAssets'] - df['Inventory']) / \
    df['CurrentLiabilities']

# %% [markdown]
# ##### Profitability Ratios

# %%
# Gross Profit Margin
required_cols += ['Gross Profit Margin']
cols += ['Gross Profit Margin']
df['Gross Profit Margin'] = df['GrossProfit'] / df['TotalRevenue']

# Net Profit Margin
required_cols += ['Net Profit Margin']
cols.append('Net Profit Margin')
df['Net Profit Margin'] = df['NetIncome'] / df['TotalRevenue']

# Cash Flow Margin
required_cols += ['Cash Flow Margin']
cols += ['Cash Flow Margin']
df['Cash Flow Margin'] = df['OperatingCashFlow'] / df['TotalRevenue']

# Operating Margin
required_cols += ['Operating Margin']
cols.append('Operating Margin')
df['Operating Margin'] = df['OperatingIncome'] / df['TotalRevenue']

# # Net Interest Margin
# # Not relevant for all companies
# cols += ['Net Interest Margin']
# df['Net Interest Margin'] = df['NetInterestIncome'] / df['TotalRevenue']

# Return on Assets (ROA)
required_cols += ['ROA']
cols += ['ROA']
df['ROA'] = df['NetIncome'] / df['TotalAssets']

# Cash Return on Assets (CROA)
required_cols += ['CROA']
cols.append('CROA')
df['CROA'] = df['OperatingCashFlow'] / df['TotalAssets']

# Return on Equity (ROE)
required_cols += ['ROE']
cols += ['ROE']
df['ROE'] = df['NetIncome'] / df['TotalEquityGrossMinorityInterest']

# %% [markdown]
# ##### Efficiency Ratios

# %%
# Efficiency Ratio (Expense as a % of Revenue)
# Not all filings report OperatingExpense and InterestExpense
cols.append('Efficiency Ratio')
df['Efficiency Ratio'] = (df['TotalExpenses'] - df['InterestExpense']) / df['TotalRevenue']

# Inventory Turnover
# Not all companies report ChangeInInventory
cols.append('Inventory Turnover')
df['Inventory Turnover'] = df['CostOfRevenue'] / df['ChangeInInventory']

# %% [markdown]
# ##### Debt Ratios

# %%
cols += ['Debt to Equity', 'Debt Ratio', 'Interest Coverage']

# Debt to Equity
required_cols += ['Debt to Equity']
df['Debt to Equity'] = df['TotalDebt'] / \
    df['TotalEquityGrossMinorityInterest']

# Debt Ratio
required_cols += ['Debt Ratio']
df['Debt Ratio'] = df['TotalDebt'] / df['TotalAssets']

# Interest Coverage
# Not all companies report InterestExpense
df['Interest Coverage'] = df['EBIT'] / df['InterestExpense']

# Cash Flow to Debt
required_cols += ['Cash Flow to Debt']
cols.append('Cash Flow to Debt')
df['Cash Flow to Debt'] = df['OperatingCashFlow'] / df['TotalDebt']

# %% [markdown]
# #### Other

# %%
# Assets to Equity
required_cols += ['Assets to Equity']
cols.append('Assets to Equity')
df['Assets to Equity'] = df['TotalAssets'] / df['TotalEquityGrossMinorityInterest']

# R&D to Revenue
# Not relevant for all companies
cols += ['R&D to Revenue']
df['R&D to Revenue'] = df['ResearchAndDevelopment'] / df['TotalRevenue']

# Investment Cash Flow to OCF
required_cols += ['Investment CF to OCF']
cols.append('Investment CF to OCF')
df['Investment CF to OCF'] = df['OperatingCashFlow'] / df['InvestingCashFlow']

# Financing Cash Flow to OCF
required_cols += ['Financing CF to OCF']
cols.append('Financing CF to OCF')
df['Financing CF to OCF'] = df['FinancingCashFlow'] / df['OperatingCashFlow']

# FCF
required_cols += ['FreeCashFlow']
cols.append('FreeCashFlow')

# Capex
required_cols += ['Capex']
cols.append('Capex')
df['Capex'] = df['OperatingCashFlow'] - df['FreeCashFlow']

# Book Value Per Share
required_cols += ['Book Value Per Share']
cols += ['Book Value Per Share']
df['Book Value Per Share'] = df['TotalEquityGrossMinorityInterest'] / \
    df['OrdinarySharesNumber']

# Tangible Book Value Per Share
required_cols += ['Tangible Book Value Per Share']
cols += ['Tangible Book Value Per Share']
df['Tangible Book Value Per Share'] = df['TangibleBookValue'] / \
    df['OrdinarySharesNumber']

# Any infs are from division by zero, we'll replace them with 0
df.replace([np.inf, -np.inf], 0, inplace=True)

# Total filings
print('Total Filings:', df.shape)

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    # Print nulls
    print('\nNulls:\n', df.dropna(subset=required_cols).isnull().sum().sort_values())
# Out:
# Total Filings: (53151, 377)
#
# Nulls:
#  symbol                                                              0
# TotalDebt                                                           0
# TotalCapitalization                                                 0
# TotalAssets                                                         0
# TaxRateForCalcs                                                     0
# TaxEffectOfUnusualItems                                             0
# TangibleBookValue                                                   0
# StockholdersEquity                                                  0
# ShareIssued                                                         0
# ReconciledCostOfRevenue                                             0
# PretaxIncome                                                        0
# OrdinarySharesNumber                                                0
# OperatingRevenue                                                    0
# OperatingIncome                                                     0
# OperatingCashFlow                                                   0
# TotalEquityGrossMinorityInterest                                    0
# NormalizedIncome                                                    0
# NetTangibleAssets                                                   0
# NetIncomeIncludingNoncontrollingInterests                           0
# NetIncomeFromContinuingOperationNetMinorityInterest                 0
# NetIncomeFromContinuingAndDiscontinuedOperation                     0
# NetIncomeContinuousOperations                                       0
# NetIncomeCommonStockholders                                         0
# Book Value Per Share                                                0
# InvestingCashFlow                                                   0
# GrossProfit                                                         0
# FreeCashFlow                                                        0
# FinancingCashFlow                                                   0
# EBITDA                                                              0
# EBIT                                                                0
# DilutedNIAvailtoComStockholders                                     0
# NormalizedEBITDA                                                    0
# TotalExpenses                                                       0
# TotalLiabilitiesNetMinorityInterest                                 0
# TotalNonCurrentAssets                                               0
# Capex                                                               0
# Financing CF to OCF                                                 0
# Investment CF to OCF                                                0
# Assets to Equity                                                    0
# Cash Flow to Debt                                                   0
# Debt Ratio                                                          0
# Debt to Equity                                                      0
# ROE                                                                 0
# CROA                                                                0
# ROA                                                                 0
# Operating Margin                                                    0
# Cash Flow Margin                                                    0
# Net Profit Margin                                                   0
# Gross Profit Margin                                                 0
# Current Ratio                                                       0
# Stock Affect Date                                                   0
# BMO/AMC                                                             0
# TotalNonCurrentLiabilitiesNetMinorityInterest                       0
# TotalRevenue                                                        0
# WorkingCapital                                                      0
# cap                                                                 0
# GICS Sector                                                         0
# GICS Sub-Industry                                                   0
# CurrentLiabilities                                                  0
# GICS Sector ID                                                      0
# GICS Industry Group                                                 0
# GICS Industry ID                                                    0
# GICS Industry                                                       0
# GICS Sub-Industry ID                                                0
# title                                                               0
# Earnings Date                                                       0
# GICS Industry Group ID                                              0
# CurrentAssets                                                       0
# NetIncome                                                           0
# Tangible Book Value Per Share                                       0
# asOfDate                                                            0
# periodType                                                          0
# currencyCode                                                        0
# CommonStockEquity                                                   0
# CashFlowFromContinuingInvestingActivities                           0
# InvestedCapital                                                     2
# CashFlowFromContinuingFinancingActivities                           2
# CostOfRevenue                                                       3
# EndCashPosition                                                     4
# ChangeInCashSupplementalAsReported                                  7
# BeginningCashPosition                                              17
# PayablesAndAccruedExpenses                                         21
# CashCashEquivalentsAndShortTermInvestments                         40
# OperatingExpense                                                   88
# CashAndCashEquivalents                                             90
# ChangesInCash                                                     110
# ReconciledDepreciation                                            286
# CapitalStock                                                      287
# CommonStock                                                       289
# CashFlowFromContinuingOperatingActivities                         311
# NetIncomeFromContinuingOperations                                 344
# DepreciationAmortizationDepletion                                 427
# RetainedEarnings                                                  448
# ChangeInWorkingCapital                                            463
# LongTermDebtAndCapitalLeaseObligation                             520
# Receivables                                                       660
# DilutedAverageShares                                              662
# BasicAverageShares                                                662
# DilutedEPS                                                        670
# BasicEPS                                                          670
# NetInterestIncome                                                1068
# NetNonOperatingInterestIncomeExpense                             1075
# AccountsReceivable                                               1411
# TaxProvision                                                     1536
# Payables                                                         1552
# CapitalExpenditure                                               1681
# AccountsPayable                                                  1723
# NetPPE                                                           1910
# OtherNonCurrentAssets                                            2237
# NetIssuancePaymentsOfDebt                                        2247
# DepreciationAndAmortization                                      2484
# SellingGeneralAndAdministration                                  2685
# LongTermDebt                                                     3172
# AdditionalPaidInCapital                                          3437
# Interest Coverage                                                3553
# InterestExpense                                                  3553
# Efficiency Ratio                                                 3553
# InterestExpenseNonOperating                                      3559
# GainsLossesNotAffectingRetainedEarnings                          3599
# OtherIncomeExpense                                               3807
# NetLongTermDebtIssuance                                          3833
# OtherNonCurrentLiabilities                                       4151
# RepaymentOfDebt                                                  4270
# GoodwillAndOtherIntangibleAssets                                 4845
# StockBasedCompensation                                           5115
# ChangeInPayablesAndAccruedExpense                                5225
# LongTermDebtPayments                                             5530
# NetOtherFinancingCharges                                         5728
# OtherNonCashItems                                                5743
# ChangeInReceivables                                              6157
# TotalOperatingIncomeAsReported                                   6764
# CurrentDebtAndCapitalLeaseObligation                             6785
# NetCommonStockIssuance                                           6900
# GrossPPE                                                         7689
# NetDebt                                                          7783
# Goodwill                                                         7977
# CurrentAccruedExpenses                                           8111
# OtherEquityAdjustments                                           8821
# DeferredTax                                                      9211
# DeferredIncomeTax                                                9211
# OtherCurrentAssets                                               9270
# NonCurrentDeferredLiabilities                                    9466
# OtherIntangibleAssets                                            9619
# IssuanceOfDebt                                                   9749
# OtherNonOperatingIncomeExpenses                                 10970
# ChangeInOtherWorkingCapital                                     10995
# TotalUnusualItems                                               11002
# TotalUnusualItemsExcludingGoodwill                              11017
# Quick Ratio                                                     11077
# Inventory                                                       11077
# RepurchaseOfCapitalStock                                        11260
# CommonStockPayments                                             11625
# CurrentDebt                                                     11635
# ChangeInPayable                                                 11823
# ChangeInAccountPayable                                          12181
# OperatingGainsLosses                                            12263
# NetPPEPurchaseAndSale                                           12408
# LongTermDebtIssuance                                            12595
# CashDividendsPaid                                               13251
# NonCurrentDeferredTaxesLiabilities                              13767
# ChangesInAccountReceivables                                     14003
# SpecialIncomeCharges                                            14111
# EffectOfExchangeRateChanges                                     14614
# NetBusinessPurchaseAndSale                                      14652
# Security                                                        15098
# PrepaidAssets                                                   15579
# AccumulatedDepreciation                                         15592
# NetOtherInvestingChanges                                        16093
# ChangeInInventory                                               16127
# Inventory Turnover                                              16137
# CommonStockDividendPaid                                         16610
# PurchaseOfPPE                                                   17108
# PurchaseOfBusiness                                              17536
# OtherProperties                                                 18545
# TreasuryStock                                                   19101
# GrossAccountsReceivable                                         19651
# NonCurrentDeferredAssets                                        19916
# PreferredStock                                                  19954
# AllowanceForDoubtfulAccountsReceivable                          20262
# TreasurySharesNumber                                            20395
# NetShortTermDebtIssuance                                        20397
# ProceedsFromStockOptionExercised                                20527
# TotalTaxPayable                                                 20710
# FinishedGoods                                                   21004
# NetInvestmentPurchaseAndSale                                    21264
# CurrentDeferredLiabilities                                      21527
# DepreciationAmortizationDepletionIncomeStatement                21874
# InterestIncome                                                  21924
# InterestIncomeNonOperating                                      21960
# MinorityInterest                                                22065
# OtherCurrentLiabilities                                         22179
# CapitalLeaseObligations                                         22233
# DepreciationAndAmortizationInIncomeStatement                    22361
# RawMaterials                                                    22711
# CurrentDeferredRevenue                                          22795
# MinorityInterests                                               22977
# LongTermCapitalLeaseObligation                                  23095
# GeneralAndAdministrativeExpense                                 23396
# CapitalExpenditureReported                                      23521
# NonCurrentDeferredTaxesAssets                                   23844
# OtherGandA                                                      24044
# ChangeInPrepaidAssets                                           24098
# InterestPaidSupplementalData                                    24557
# InvestmentsAndAdvances                                          24580
# PurchaseOfInvestment                                            24982
# ChangeInOtherCurrentAssets                                      25030
# SaleOfInvestment                                                25270
# ChangeInAccruedExpense                                          25702
# OtherCurrentBorrowings                                          26175
# IncomeTaxPaidSupplementalData                                   26516
# PensionandOtherPostRetirementBenefitPlansCurrent                26637
# RestructuringAndMergernAcquisition                              26644
# ChangeInOtherCurrentLiabilities                                 27033
# MachineryFurnitureEquipment                                     27046
# WorkInProcess                                                   27520
# Properties                                                      27626
# IncomeTaxPayable                                                27675
# CurrentCapitalLeaseObligation                                   28393
# Depreciation                                                    28576
# EmployeeBenefits                                                28684
# IssuanceOfCapitalStock                                          28949
# GainOnSaleOfSecurity                                            29083
# CommonStockIssuance                                             29182
# OtherReceivables                                                29196
# SaleOfPPE                                                       29354
# AssetImpairmentCharge                                           29520
# OtherOperatingExpenses                                          29830
# ShortTermDebtIssuance                                           29879
# OtherShortTermInvestments                                       30189
# ResearchAndDevelopment                                          30211
# R&D to Revenue                                                  30211
# ShortTermDebtPayments                                           30347
# LandAndImprovements                                             30690
# NonCurrentPensionAndOtherPostretirementBenefitPlans             31168
# ConstructionInProgress                                          31224
# BuildingsAndImprovements                                        31226
# EarningsLossesFromEquityInvestments                             31446
# RestrictedCash                                                  32046
# ProvisionandWriteOffofAssets                                    32071
# GainLossOnInvestmentSecurities                                  32492
# EarningsFromEquityInterest                                      32556
# LongTermEquityInvestment                                        32640
# ChangeInTaxPayable                                              32792
# ChangeInIncomeTaxPayable                                        32796
# AmortizationOfIntangibles                                       32986
# AmortizationCashFlow                                            32987
# GainLossOnSaleOfPPE                                             33398
# SaleOfBusiness                                                  33694
# NonCurrentDeferredRevenue                                       33701
# InterestPayable                                                 33748
# TaxesReceivable                                                 34076
# SellingAndMarketingExpense                                      34213
# TotalOtherFinanceCost                                           34424
# ImpairmentOfCapitalAssets                                       34522
# CurrentDeferredAssets                                           34775
# OtherSpecialCharges                                             34818
# AmortizationOfIntangiblesIncomeStatement                        34830
# Amortization                                                    34830
# NetIncomeDiscontinuousOperations                                35003
# GainOnSaleOfPPE                                                 35334
# OtherunderPreferredStockDividend                                35564
# AssetsHeldForSaleCurrent                                        35841
# PensionAndEmployeeBenefitExpense                                36032
# TradeandOtherPayablesNonCurrent                                 36167
# LineOfCredit                                                    36305
# Leases                                                          36329
# CurrentDeferredTaxesAssets                                      36502
# DividendsPayable                                                36557
# GainLossOnSaleOfBusiness                                        37097
# OtherPayable                                                    37184
# LongTermProvisions                                              37439
# WriteOff                                                        37522
# CurrentProvisions                                               37669
# ExcessTaxBenefitFromStockBasedCompensation                      37833
# NetIntangiblesPurchaseAndSale                                   37836
# InvestmentinFinancialAssets                                     37852
# PreferredSecuritiesOutsideStockEquity                           38086
# InventoriesAdjustmentsAllowances                                38117
# PurchaseOfIntangibles                                           38131
# DividendReceivedCFO                                             38371
# GainOnSaleOfBusiness                                            38485
# AverageDilutionEarnings                                         38546
# SalariesAndWages                                                38560
# NonCurrentAccountsReceivable                                    38578
# NetForeignCurrencyExchangeGainLoss                              38691
# EarningsFromEquityInterestNetOfTax                              38731
# OtherInvestments                                                38733
# InvestmentProperties                                            38996
# NetInvestmentPropertiesPurchaseAndSale                          39143
# PreferredStockDividends                                         39180
# OtherInventories                                                39189
# NonCurrentPrepaidAssets                                         39223
# ReceivablesAdjustmentsAllowances                                39273
# DerivativeProductLiabilities                                    39327
# PurchaseOfInvestmentProperties                                  39357
# RentExpenseSupplemental                                         39392
# CashFromDiscontinuedOperatingActivities                         39442
# OtherTaxes                                                      39538
# AvailableForSaleSecurities                                      39542
# InvestmentsinAssociatesatCost                                   39566
# CashFinancial                                                   39634
# PreferredStockEquity                                            39642
# AmortizationOfSecurities                                        39863
# PreferredSharesNumber                                           39893
# HedgingAssetsCurrent                                            39914
# CurrentNotesPayable                                             39931
# DividendsReceivedCFI                                            39988
# FinancialAssets                                                 40006
# DefinedPensionBenefit                                           40176
# DepreciationIncomeStatement                                     40189
# OtherEquityInterest                                             40249
# SaleOfInvestmentProperties                                      40265
# CashFromDiscontinuedInvestingActivities                         40265
# NonCurrentAccruedExpenses                                       40521
# CommercialPaper                                                 40640
# NotesReceivable                                                 40725
# CashEquivalents                                                 40730
# InvestmentsinJointVenturesatCost                                40741
# PreferredStockDividendPaid                                      40801
# NonCurrentNoteReceivables                                       40861
# UnrealizedGainLossOnInvestmentSecurities                        40868
# ChangeInInterestPayable                                         40962
# LiabilitiesHeldforSaleNonCurrent                                41067
# CurrentDeferredTaxesLiabilities                                 41176
# DuefromRelatedPartiesCurrent                                    41202
# RentAndLandingFees                                              41229
# LoansReceivable                                                 41275
# DuetoRelatedPartiesCurrent                                      41305
# CashFromDiscontinuedFinancingActivities                         41398
# NetPreferredStockIssuance                                       41442
# ProvisionForDoubtfulAccounts                                    41673
# OtherCapitalStock                                               41767
# MinimumPensionLiabilities                                       41798
# InvestmentsInOtherVenturesUnderEquityMethod                     41814
# ForeignCurrencyTranslationAdjustments                           41859
# OtherCashAdjustmentOutsideChangeinCash                          41884
# PreferredStockPayments                                          41970
# HeldToMaturitySecurities                                        42006
# InsuranceAndClaims                                              42096
# PreferredStockIssuance                                          42098
# CashFlowFromDiscontinuedOperation                               42141
# InvestmentsinSubsidiariesatCost                                 42288
# AccruedInterestReceivable                                       42345
# SaleOfIntangibles                                               42368
# ExciseTaxes                                                     42393
# DuetoRelatedPartiesNonCurrent                                   42425
# Depletion                                                       42443
# TradingSecurities                                               42455
# UnrealizedGainLoss                                              42467
# InterestReceivedCFI                                             42482
# TaxesRefundPaid                                                 42482
# NetIncomeExtraordinary                                          42492
# InterestPaidCFF                                                 42519
# OtherCashAdjustmentInsideChangeinCash                           42566
# DuefromRelatedPartiesNonCurrent                                 42578
# FinancialAssetsDesignatedasFairValueThroughProfitorLossTotal    42597
# SecuritiesAmortization                                          42615
# ForeignSales                                                    42615
# DomesticSales                                                   42615
# NetIncomeFromTaxLossCarryforward                                42652
# InterestPaidCFO                                                 42663
# RestrictedCommonStock                                           42668
# DividendPaidCFO                                                 42679
# ChangeInDividendPayable                                         42683
# DepletionIncomeStatement                                        42697
# InterestReceivedCFO                                             42697
# AdjustedGeographySegmentData                                    42716
# TotalPartnershipCapital                                         42726
# OtherCashReceiptsfromOperatingActivities                        42727
# GeneralPartnershipCapital                                       42727
# ClassesofCashPayments                                           42727
# PaymentsonBehalfofEmployees                                     42727
# FixedAssetsRevaluationReserve                                   42727
# CashFlowsfromusedinOperatingActivitiesDirect                    42727
# LimitedPartnershipCapital                                       42727
# OtherCashPaymentsfromOperatingActivities                        42727
# ClassesofCashReceiptsfromOperatingActivities                    42727
# dtype: int64

# %% [markdown]
# #### Percent Change

# %%
# Re-sort
def sort_cols(df: pd.DataFrame, cols: list) -> pd.DataFrame:
    return df[cols]

df = sort_cols(df, cat_cols + ['asOfDate', 'Stock Affect Date'] + [col for col in cols])
df = df.sort_values(['symbol', 'Stock Affect Date']).reset_index(drop=True)

pd.set_option('display.max_columns', None)

# %%
display(df.query('symbol == "UNFI"').tail(30))

# Calculate the difference in quarters between current and previous report for the same company
df['quarter_diff'] = (df.groupby('symbol', observed=True)['asOfDate'].diff() / pd.Timedelta(90, 'days')).round()

# Identify where the streak of consecutive quarters breaks
df['streak_id'] = (df['quarter_diff'] != 1).cumsum()

# Group by each streak and calculate the percentage change within the streak
# Note: Since we are dealing with potentially negative numbers, we'll use the absolute value in the denominator
# not sure why pandas default pct_change method doesn't use this formula or at least have it as an option
df[cols] = df.groupby(['symbol', 'streak_id'], observed=True)[
    cols].diff() / abs(df.groupby(['symbol', 'streak_id'], observed=True)[cols].shift())

# Drop streak ID and quarter diff and asOfDate
df.drop(columns=['streak_id', 'quarter_diff', 'asOfDate'], inplace=True)

# Any infinities are from division by zero, we'll replace them with 0
df.replace([np.inf, -np.inf], 0, inplace=True)

print('Percent Change')
display(df.query('symbol == "UNFI"').tail(30))

# Print Nulls
print(df.shape)
print(df.isnull().sum().sort_values())
# Out:
#       symbol    cap GICS Sector ID       GICS Sector GICS Industry Group ID  \
# 48662   UNFI  small             30  Consumer Staples                   3010
# 48663   UNFI  small             30  Consumer Staples                   3010
# 48664   UNFI  small             30  Consumer Staples                   3010
# 48665   UNFI  small             30  Consumer Staples                   3010
# 48666   UNFI  small             30  Consumer Staples                   3010
# 48667   UNFI  small             30  Consumer Staples                   3010
# 48668   UNFI  small             30  Consumer Staples                   3010
# 48669   UNFI  small             30  Consumer Staples                   3010
# 48670   UNFI  small             30  Consumer Staples                   3010
# 48671   UNFI  small             30  Consumer Staples                   3010
# 48672   UNFI  small             30  Consumer Staples                   3010
# 48673   UNFI  small             30  Consumer Staples                   3010
# 48674   UNFI  small             30  Consumer Staples                   3010
# 48675   UNFI  small             30  Consumer Staples                   3010
# 48676   UNFI  small             30  Consumer Staples                   3010
# 48677   UNFI  small             30  Consumer Staples                   3010
# 48678   UNFI  small             30  Consumer Staples                   3010
# 48679   UNFI  small             30  Consumer Staples                   3010
# 48680   UNFI  small             30  Consumer Staples                   3010
# 48681   UNFI  small             30  Consumer Staples                   3010
# 48682   UNFI  small             30  Consumer Staples                   3010
# 48683   UNFI  small             30  Consumer Staples                   3010
# 48684   UNFI  small             30  Consumer Staples                   3010
# 48685   UNFI  small             30  Consumer Staples                   3010
# 48686   UNFI  small             30  Consumer Staples                   3010
# 48687   UNFI  small             30  Consumer Staples                   3010
# 48688   UNFI  small             30  Consumer Staples                   3010
# EBITDA                           12675
# Current Ratio                    12714
# Gross Profit Margin              13071
# Efficiency Ratio                 15648
# Interest Coverage                15836
# Quick Ratio                      23531
# Inventory Turnover               28281
# R&D to Revenue                   40552
# dtype: int64

# %%
# Mark days with an earnings call
df['Earnings Call'] = 1

# Get valid tickers and reset categories
valid_tickers = df['symbol'].unique()
df['symbol'] = df['symbol'].cat.set_categories(valid_tickers)

# %% [markdown]
# ##### Stock Price

# %%
# Grab stock prices
df_stock = pd.concat([pd.read_csv(f'data/{cap}/stock_hist.csv')[['symbol', 'date', 'adjclose']]
                      for cap in ['large', 'mid', 'small']])
cols = ['date', 'adjclose'] + cols
df_stock['date'] = df_stock['date'].str[:10]

# Valid tickers
df_stock = df_stock[df_stock['symbol'].isin(valid_tickers)]
df_stock['symbol'] = df_stock['symbol'].astype(df['symbol'].dtype)

df['Stock Affect Date'] = df['Stock Affect Date'].astype('datetime64[ns]')

df_stock['Stock Affect Date'] = df_stock['date']
df_stock['Stock Affect Date'] = df_stock['Stock Affect Date'].astype('datetime64[ns]')

# Merge stock prices with financials
df = pd.merge_asof(df_stock.sort_values('Stock Affect Date'), df.sort_values('Stock Affect Date'), on='Stock Affect Date', by='symbol', tolerance=pd.Timedelta(days=0))
# %xdel df_stock

print('Total:', df.shape)
display(df.head(3))
# Drop invalid tickers
df = df[df['symbol'].isin(valid_tickers)]
# Out:
# Total: (3715142, 44)
#   symbol        date   adjclose Stock Affect Date  cap GICS Sector ID  \
# 0    MMM  2013-07-29  81.858749        2013-07-29  NaN            NaN
# 1     ON  2013-07-29   8.100000        2013-07-29  NaN            NaN
# 2    OKE  2013-07-29  23.889841        2013-07-29  NaN            NaN
#
#   GICS Sector GICS Industry Group ID GICS Industry Group GICS Industry ID  \
# 0         NaN                    NaN                 NaN              NaN
# 1         NaN                    NaN                 NaN              NaN
# 2         NaN                    NaN                 NaN              NaN
#
#   GICS Industry GICS Sub-Industry ID GICS Sub-Industry  TotalRevenue  \
# 0           NaN                  NaN               NaN           NaN
# 1           NaN                  NaN               NaN           NaN
# 2           NaN                  NaN               NaN           NaN
#
#    OperatingRevenue  NetIncome  BasicEPS  DilutedEPS  EBITDA  EBIT  \
# 0               NaN        NaN       NaN         NaN     NaN   NaN
# 1               NaN        NaN       NaN         NaN     NaN   NaN
# 2               NaN        NaN       NaN         NaN     NaN   NaN
#
#    Current Ratio  Quick Ratio  Gross Profit Margin  Net Profit Margin  \
# 0            NaN          NaN                  NaN                NaN
# 1            NaN          NaN                  NaN                NaN
# 2            NaN          NaN                  NaN                NaN
#
#    Cash Flow Margin  Operating Margin  ROA  CROA  ROE  Efficiency Ratio  \
# 0               NaN               NaN  NaN   NaN  NaN               NaN
# 1               NaN               NaN  NaN   NaN  NaN               NaN
# 2               NaN               NaN  NaN   NaN  NaN               NaN
#
#    Inventory Turnover  Debt to Equity  Debt Ratio  Interest Coverage  \
# 0                 NaN             NaN         NaN                NaN
# 1                 NaN             NaN         NaN                NaN
# 2                 NaN             NaN         NaN                NaN
#
#    Cash Flow to Debt  Assets to Equity  R&D to Revenue  Investment CF to OCF  \
# 0                NaN               NaN             NaN                   NaN
# 1                NaN               NaN             NaN                   NaN
# 2                NaN               NaN             NaN                   NaN
#
#    Financing CF to OCF  FreeCashFlow  Capex  Book Value Per Share  \
# 0                  NaN           NaN    NaN                   NaN
# 1                  NaN           NaN    NaN                   NaN
# 2                  NaN           NaN    NaN                   NaN
#
#    Tangible Book Value Per Share  Earnings Call
# 0                            NaN            NaN
# 1                            NaN            NaN
# 2                            NaN            NaN

# %%
# Fill cat_cols
group = df.groupby('symbol', observed=True)
for col in cat_cols:
    df[col] = group[col].ffill()
    df[col] = group[col].bfill()
# %xdel group
    
# Drop any remaining nulls in cat_cols
df = df.dropna(subset=cat_cols)

print(df.shape)
print(df.isnull().sum())
# Out:
# (3715142, 44)
# symbol                                 0
# date                                   0
# adjclose                               0
# Stock Affect Date                      0
# cap                                    0
# GICS Sector ID                         0
# GICS Sector                            0
# GICS Industry Group ID                 0
# GICS Industry Group                    0
# GICS Industry ID                       0
# GICS Industry                          0
# GICS Sub-Industry ID                   0
# GICS Sub-Industry                      0
# TotalRevenue                     3667844
# OperatingRevenue                 3667844
# NetIncome                        3667815
# BasicEPS                         3669356
# DilutedEPS                       3669356
# EBITDA                           3674869
# EBIT                             3672965
# Current Ratio                    3674891
# Quick Ratio                      3685643
# Gross Profit Margin              3675253
# Net Profit Margin                3667844
# Cash Flow Margin                 3667902
# Operating Margin                 3674856
# ROA                              3667837
# CROA                             3667892
# ROE                              3667837
# Efficiency Ratio                 3677824
# Inventory Turnover               3690355
# Debt to Equity                   3670366
# Debt Ratio                       3670366
# Interest Coverage                3678012
# Cash Flow to Debt                3670426
# Assets to Equity                 3667825
# R&D to Revenue                   3702551
# Investment CF to OCF             3667904
# Financing CF to OCF              3667906
# FreeCashFlow                     3667828
# Capex                            3670733
# Book Value Per Share             3667826
# Tangible Book Value Per Share    3667826
# Earnings Call                    3662294
# dtype: int64

# %% [markdown]
# ##### Macros

# %%
def get_macro(path: str, freq: str) -> pd.DataFrame:
    # All are forward filled as data is not published on federal holidays, despite some being trading days
    df = pd.read_csv(f'data/macro/{path}.csv')
    if freq == 'weekly':
        df = df[['realtime_start', 'date', 'value']]
        df.columns = ['date', 'week', f'{path}']
        df['date'] = df['date'].astype('datetime64[ns]')
        df['week'] = df['week'].astype('datetime64[ns]')
        df.set_index('date', inplace=True)
        # Only keep when date published is the same
        df = df[df.index == df['week']]
        df.drop(columns=['week'], inplace=True)
        # Ensure our weeklies line up with all trading dates
        df = df.asfreq(bday, method='ffill') 
        return df

    elif freq == 'monthly':
        df = df[['realtime_start', 'date', 'value']]
        df.columns = ['date', 'month', f'{path}']
        df['date'] = df['date'].astype('datetime64[ns]')
        df['month'] = df['month'].astype('datetime64[ns]')
        df.set_index('date', inplace=True)
        # Only keep when date published is in the following month
        df = df[df.index <= df['month'] + pd.DateOffset(months=2)]
        df.drop(columns=['month'], inplace=True)
        # Forward fill
        df.ffill(inplace=True)
        return df.diff() / abs(df.shift())

    elif freq == 'quarterly':
        df = df[['realtime_start', 'date', 'value']]
        df.columns = ['date', 'quarter', f'{path}']
        df['date'] = df['date'].astype('datetime64[ns]')
        df['quarter'] = df['quarter'].astype('datetime64[ns]')
        df.set_index('date', inplace=True)
        # Only keep when date published is in the following quarter
        df = df[df.index <= df['quarter'] + pd.DateOffset(months=4)]
        df.drop(columns=['quarter'], inplace=True)
        # Forward fill
        df.ffill(inplace=True)
        return df.diff() / abs(df.shift())

    # We need some extra work for the pct_change later for the dailies
    elif freq == 'daily':
        df.columns = ['date', f'{path}']
        df['date'] = df['date'].astype('datetime64[ns]')
        df.set_index('date', inplace=True)
        # Ensure our dailies line up with all trading dates
        df = df.asfreq(bday, method='ffill')
        return df


# Dailies
# These are going to need some extra work for percent change after resampling to monthly
dailies = ['fed_funds', 'treasury_10yr', 'treasury_2yr',
           'baa_credit_spread', 'aaa_credit_spread']
cols_need_pchange = dailies.copy()
cols += dailies

fed_funds, treasury_10yr, treasury_2yr, baa_credit_spread, aaa_credit_spread = [
    get_macro(path, 'daily') for path in dailies]


def get_index(path: str) -> pd.DataFrame:
    df = pd.read_csv(f'data/macro/{path}.csv')[['date', 'adjclose']]
    df.columns = ['date', path]
    df['date'] = pd.to_datetime(df['date'])
    df.set_index('date', inplace=True)
    # Ensure all my indexes line up with all trading dates 
    # (ex. ^IRX is closed on some federal holidays that are trading days)
    df = df.asfreq(bday, method='ffill')
    return df


dailies_index = ['treasury_3mo', 'vix', 'gold', 'oil', 'silver', 'copper', 'aluminium', 'platinum', 'palladium', 'natural_gas', 'wheat', 'corn', 'soybean', 'coffee', 'cocao', 'sugar', 'cotton']
cols_need_pchange += dailies_index
cols += dailies_index
treasury_3mo, vix, gold, oil, silver, copper, aluminium, platinum, palladium, natural_gas, wheat, corn, soybean, coffee, cocao, sugar, cotton = [get_index(path) for path in dailies_index]
dailies += dailies_index

# Weeklies
weeklies = ['mortgage_30yr', 'mortgage_15yr']
cols_need_pchange += weeklies
cols += weeklies
mortgage_30yr, mortgage_15yr = [
    get_macro(path, 'weekly') for path in weeklies]

# Monthlies
monthlies = ['cpi', 'unemployment', 'federal_budget_deficit', 'housing_starts']
cols += monthlies

cpi, unemployment, federal_budget_deficit, housing_starts = [
    get_macro(path, 'monthly') for path in monthlies]

# Quarterlies
quarterlies = ['gdp_real', 'avg_home_price']
cols += quarterlies
gdp_real, avg_home_price = [get_macro(path, 'quarterly') for path in quarterlies]

# Any infs are from division by zero, we'll replace them with 0
for var in dailies + weeklies + monthlies + quarterlies:
    globals()[var].replace([np.inf, -np.inf], 0, inplace=True)

print(cols_need_pchange, dailies, weeklies, monthlies, quarterlies, sep='\n')
# Out:
# ['fed_funds', 'treasury_10yr', 'treasury_2yr', 'baa_credit_spread', 'aaa_credit_spread', 'treasury_3mo', 'vix', 'gold', 'oil', 'silver', 'copper', 'aluminium', 'platinum', 'palladium', 'natural_gas', 'wheat', 'corn', 'soybean', 'coffee', 'cocao', 'sugar', 'cotton', 'mortgage_30yr', 'mortgage_15yr']
# ['fed_funds', 'treasury_10yr', 'treasury_2yr', 'baa_credit_spread', 'aaa_credit_spread', 'treasury_3mo', 'vix', 'gold', 'oil', 'silver', 'copper', 'aluminium', 'platinum', 'palladium', 'natural_gas', 'wheat', 'corn', 'soybean', 'coffee', 'cocao', 'sugar', 'cotton']
# ['mortgage_30yr', 'mortgage_15yr']
# ['cpi', 'unemployment', 'federal_budget_deficit', 'housing_starts']
# ['gdp_real', 'avg_home_price']

# %%
# Merge macros with financials & stock prices
df['date'] = df['date'].astype('datetime64[ns]')
for name in dailies + weeklies + monthlies + quarterlies:
	var = globals()[name]
	df = pd.merge_asof(df.sort_values('date'), var.sort_values('date'), on='date', tolerance=pd.Timedelta(days=0))

# %reset_selective -f fed_funds treasury_10yr treasury_2yr treasury_3mo baa_credit_spread aaa_credit_spread gold oil vix mortgage_30yr mortgage_15yr cpi unemployment federal_budget_deficit housing_starts gdp avg_home_price

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
	display(df.head(5))
	print('\nNulls:\n', df.isnull().sum().sort_values())
# Out:
#   symbol       date   adjclose Stock Affect Date    cap GICS Sector ID  \
# 0    MMM 2013-07-29  81.858749        2013-07-29  large             20
# 1   SLCA 2013-07-29  21.858809        2013-07-29  small             10
# 2   XRAY 2013-07-29  38.631176        2013-07-29  large             35
# 3     FE 2013-07-29  24.726622        2013-07-29  large             55
# 4    LLY 2013-07-29  42.245495        2013-07-29  large             35
#
#    GICS Sector GICS Industry Group ID  \
# 0  Industrials                   2010
# 1       Energy                   1010
# 2  Health Care                   3510
# 3    Utilities                   5510
# 4  Health Care                   3520
#
#                               GICS Industry Group GICS Industry ID  \
# 0                                   Capital Goods         201050.0
# 1                                          Energy         101010.0
# 2                Health Care Equipment & Services         351010.0
# 3                                       Utilities         551010.0
# 4  Pharmaceuticals, Biotechnology & Life Sciences         352020.0
#
#                       GICS Industry GICS Sub-Industry ID  \
# 0          Industrial Conglomerates           20105010.0
# 1       Energy Equipment & Services           10101020.0
# 2  Health Care Equipment & Supplies           35101020.0
# 3                Electric Utilities           55101010.0
# 4                   Pharmaceuticals           35202010.0
#
#                 GICS Sub-Industry  TotalRevenue  OperatingRevenue  NetIncome  \
# 0        Industrial Conglomerates           NaN               NaN        NaN
# 1  Oil & Gas Equipment & Services           NaN               NaN        NaN
# 2            Health Care Supplies           NaN               NaN        NaN
# 3              Electric Utilities           NaN               NaN        NaN
# 4                 Pharmaceuticals           NaN               NaN        NaN
#
#    BasicEPS  DilutedEPS  EBITDA  EBIT  Current Ratio  Quick Ratio  \
# 0       NaN         NaN     NaN   NaN            NaN          NaN
# 1       NaN         NaN     NaN   NaN            NaN          NaN
# 2       NaN         NaN     NaN   NaN            NaN          NaN
# 3       NaN         NaN     NaN   NaN            NaN          NaN
# 4       NaN         NaN     NaN   NaN            NaN          NaN
#
#    Gross Profit Margin  Net Profit Margin  Cash Flow Margin  Operating Margin  \
# 0                  NaN                NaN               NaN               NaN
# 1                  NaN                NaN               NaN               NaN
# 2                  NaN                NaN               NaN               NaN
# 3                  NaN                NaN               NaN               NaN
# 4                  NaN                NaN               NaN               NaN
#
#    ROA  CROA  ROE  Efficiency Ratio  Inventory Turnover  Debt to Equity  \
# 0  NaN   NaN  NaN               NaN                 NaN             NaN
# 1  NaN   NaN  NaN               NaN                 NaN             NaN
# 2  NaN   NaN  NaN               NaN                 NaN             NaN
# 3  NaN   NaN  NaN               NaN                 NaN             NaN
# 4  NaN   NaN  NaN               NaN                 NaN             NaN
#
#    Debt Ratio  Interest Coverage  Cash Flow to Debt  Assets to Equity  \
# 0         NaN                NaN                NaN               NaN
# 1         NaN                NaN                NaN               NaN
# 2         NaN                NaN                NaN               NaN
# 3         NaN                NaN                NaN               NaN
# 4         NaN                NaN                NaN               NaN
#
#    R&D to Revenue  Investment CF to OCF  Financing CF to OCF  FreeCashFlow  \
# 0             NaN                   NaN                  NaN           NaN
# 1             NaN                   NaN                  NaN           NaN
# 2             NaN                   NaN                  NaN           NaN
# 3             NaN                   NaN                  NaN           NaN
# 4             NaN                   NaN                  NaN           NaN
#
#    Capex  Book Value Per Share  Tangible Book Value Per Share  Earnings Call  \
# 0    NaN                   NaN                            NaN            NaN
# 1    NaN                   NaN                            NaN            NaN
# 2    NaN                   NaN                            NaN            NaN
# 3    NaN                   NaN                            NaN            NaN
# 4    NaN                   NaN                            NaN            NaN
#
#    fed_funds  treasury_10yr  treasury_2yr  baa_credit_spread  \
# 0       0.08           2.61          0.33               2.69
# 1       0.08           2.61          0.33               2.69
# 2       0.08           2.61          0.33               2.69
# 3       0.08           2.61          0.33               2.69
# 4       0.08           2.61          0.33               2.69
#
#    aaa_credit_spread  treasury_3mo    vix         gold         oil  silver  \
# 0               1.76          0.02  13.39  1328.400024  104.550003  19.854
# 1               1.76          0.02  13.39  1328.400024  104.550003  19.854
# 2               1.76          0.02  13.39  1328.400024  104.550003  19.854
# 3               1.76          0.02  13.39  1328.400024  104.550003  19.854
# 4               1.76          0.02  13.39  1328.400024  104.550003  19.854
#
#    copper  aluminium     platinum  palladium  natural_gas  wheat    corn  \
# 0  3.1165        NaN  1441.800049     743.75        3.459  651.5  489.25
# 1  3.1165        NaN  1441.800049     743.75        3.459  651.5  489.25
# 2  3.1165        NaN  1441.800049     743.75        3.459  651.5  489.25
# 3  3.1165        NaN  1441.800049     743.75        3.459  651.5  489.25
# 4  3.1165        NaN  1441.800049     743.75        3.459  651.5  489.25
#
#    soybean      coffee   cocao  sugar     cotton  mortgage_30yr  \
# 0   1367.5  121.150002  2280.0  16.92  84.849998           4.31
# 1   1367.5  121.150002  2280.0  16.92  84.849998           4.31
# 2   1367.5  121.150002  2280.0  16.92  84.849998           4.31
# 3   1367.5  121.150002  2280.0  16.92  84.849998           4.31
# 4   1367.5  121.150002  2280.0  16.92  84.849998           4.31
#
#    mortgage_15yr  cpi  unemployment  federal_budget_deficit  housing_starts  \
# 0           3.39  NaN           NaN                     NaN             NaN
# 1           3.39  NaN           NaN                     NaN             NaN
# 2           3.39  NaN           NaN                     NaN             NaN
# 3           3.39  NaN           NaN                     NaN             NaN
# 4           3.39  NaN           NaN                     NaN             NaN
#
#    gdp_real  avg_home_price
# 0       NaN             NaN
# 1       NaN             NaN
# 2       NaN             NaN
# 3       NaN             NaN
# 4       NaN             NaN
# Nulls:
#  symbol                                 0
# GICS Sub-Industry                      0
# GICS Industry                          0
# GICS Industry ID                       0
# GICS Industry Group                    0
# GICS Industry Group ID                 0
# GICS Sub-Industry ID                   0
# GICS Sector ID                         0
# cap                                    0
# Stock Affect Date                      0
# adjclose                               0
# date                                   0
# GICS Sector                            0
# natural_gas                         1475
# palladium                           1475
# platinum                            1475
# copper                              1475
# gold                                1475
# oil                                 1475
# vix                                 1475
# treasury_3mo                        1475
# wheat                               1475
# silver                              1475
# corn                                1475
# cocao                               1475
# coffee                              1475
# fed_funds                           1475
# sugar                               1475
# cotton                              1475
# mortgage_30yr                       1475
# mortgage_15yr                       1475
# soybean                             1475
# treasury_10yr                      29334
# treasury_2yr                       29334
# baa_credit_spread                  30720
# aaa_credit_spread                  30720
# aluminium                         246386
# cpi                              3540378
# unemployment                     3541887
# housing_starts                   3544312
# federal_budget_deficit           3576746
# gdp_real                         3657747
# Earnings Call                    3662294
# avg_home_price                   3666956
# NetIncome                        3667815
# Assets to Equity                 3667825
# Book Value Per Share             3667826
# Tangible Book Value Per Share    3667826
# FreeCashFlow                     3667828
# ROE                              3667837
# ROA                              3667837
# TotalRevenue                     3667844
# OperatingRevenue                 3667844
# Net Profit Margin                3667844
# CROA                             3667892
# Cash Flow Margin                 3667902
# Investment CF to OCF             3667904
# Financing CF to OCF              3667906
# DilutedEPS                       3669356
# BasicEPS                         3669356
# Debt Ratio                       3670366
# Debt to Equity                   3670366
# Cash Flow to Debt                3670426
# Capex                            3670733
# EBIT                             3672965
# Operating Margin                 3674856
# EBITDA                           3674869
# Current Ratio                    3674891
# Gross Profit Margin              3675253
# Efficiency Ratio                 3677824
# Interest Coverage                3678012
# Quick Ratio                      3685643
# Inventory Turnover               3690355
# R&D to Revenue                   3702551
# dtype: int64

# %% [markdown]
# ##### Resample

# %%
print(df.shape)
display(df.head(3))

# Resample to monthly
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
df = df.groupby('symbol', observed=True).resample(
    'BME', include_groups=False, fill_method='ffill').last()

print(df.shape)
print('\nResampled to Monthly:')

# Reset index and sort
df.reset_index(inplace=True)
df.sort_values(['symbol', 'date'], inplace=True)

display(df.head(5))

# Apply percent change
print('\nApply Precent Change')
# Adjusted close
df['adjclose'] = df.groupby('symbol', observed=True)['adjclose'].diff() / abs(df.groupby('symbol', observed=True)['adjclose'].shift())
# Weeklies and dailies
for col in cols_need_pchange:
    df[col] = df.groupby('symbol', observed=True)[col].diff() / abs(df.groupby('symbol', observed=True)[col].shift())

display(df.head(5))

# Any infs are from division by zero, we'll replace them with 0
df.replace([np.inf, -np.inf], 0, inplace=True)

# Drop where an earnings call occurred and required columns are null
df = df[~((df['Earnings Call'] == 1) & df[required_cols].isnull().any(axis=1))]
# Drop Earnings call column
df.drop(columns=['Earnings Call'], inplace=True)

# Sort cols
df = sort_cols(df, cat_cols + [col for col in cols])

print(df.shape)
display(df.head(3))

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print('\nNulls:\n', df.isnull().sum().sort_values())
# Out:
# (3715142, 74)
#   symbol       date   adjclose Stock Affect Date    cap GICS Sector ID  \
# 0    MMM 2013-07-29  81.858749        2013-07-29  large             20
# 1   SLCA 2013-07-29  21.858809        2013-07-29  small             10
# 2   XRAY 2013-07-29  38.631176        2013-07-29  large             35
#
#    GICS Sector GICS Industry Group ID               GICS Industry Group  \
# 0  Industrials                   2010                     Capital Goods
# 1       Energy                   1010                            Energy
# 2  Health Care                   3510  Health Care Equipment & Services
#
#   GICS Industry ID                     GICS Industry GICS Sub-Industry ID  \
# 0         201050.0          Industrial Conglomerates           20105010.0
# 1         101010.0       Energy Equipment & Services           10101020.0
# 2         351010.0  Health Care Equipment & Supplies           35101020.0
#
#                 GICS Sub-Industry  TotalRevenue  OperatingRevenue  NetIncome  \
# 0        Industrial Conglomerates           NaN               NaN        NaN
# 1  Oil & Gas Equipment & Services           NaN               NaN        NaN
# 2            Health Care Supplies           NaN               NaN        NaN
#
#    BasicEPS  DilutedEPS  EBITDA  EBIT  Current Ratio  Quick Ratio  \
# 0       NaN         NaN     NaN   NaN            NaN          NaN
# 1       NaN         NaN     NaN   NaN            NaN          NaN
# 2       NaN         NaN     NaN   NaN            NaN          NaN
#
#    Gross Profit Margin  Net Profit Margin  Cash Flow Margin  Operating Margin  \
# 0                  NaN                NaN               NaN               NaN
# 1                  NaN                NaN               NaN               NaN
# 2                  NaN                NaN               NaN               NaN
#
#    ROA  CROA  ROE  Efficiency Ratio  Inventory Turnover  Debt to Equity  \
# 0  NaN   NaN  NaN               NaN                 NaN             NaN
# 1  NaN   NaN  NaN               NaN                 NaN             NaN
# 2  NaN   NaN  NaN               NaN                 NaN             NaN
#
#    Debt Ratio  Interest Coverage  Cash Flow to Debt  Assets to Equity  \
# 0         NaN                NaN                NaN               NaN
# 1         NaN                NaN                NaN               NaN
# 2         NaN                NaN                NaN               NaN
#
#    R&D to Revenue  Investment CF to OCF  Financing CF to OCF  FreeCashFlow  \
# 0             NaN                   NaN                  NaN           NaN
# 1             NaN                   NaN                  NaN           NaN
# 2             NaN                   NaN                  NaN           NaN
#
#    Capex  Book Value Per Share  Tangible Book Value Per Share  Earnings Call  \
# 0    NaN                   NaN                            NaN            NaN
# 1    NaN                   NaN                            NaN            NaN
# 2    NaN                   NaN                            NaN            NaN
#
#    fed_funds  treasury_10yr  treasury_2yr  baa_credit_spread  \
# 0       0.08           2.61          0.33               2.69
# 1       0.08           2.61          0.33               2.69
# 2       0.08           2.61          0.33               2.69
#
#    aaa_credit_spread  treasury_3mo    vix         gold         oil  silver  \
# 0               1.76          0.02  13.39  1328.400024  104.550003  19.854
# 1               1.76          0.02  13.39  1328.400024  104.550003  19.854
# 2               1.76          0.02  13.39  1328.400024  104.550003  19.854
#
#    copper  aluminium     platinum  palladium  natural_gas  wheat    corn  \
# 0  3.1165        NaN  1441.800049     743.75        3.459  651.5  489.25
# 1  3.1165        NaN  1441.800049     743.75        3.459  651.5  489.25
# 2  3.1165        NaN  1441.800049     743.75        3.459  651.5  489.25
#
#    soybean      coffee   cocao  sugar     cotton  mortgage_30yr  \
# 0   1367.5  121.150002  2280.0  16.92  84.849998           4.31
# 1   1367.5  121.150002  2280.0  16.92  84.849998           4.31
# 2   1367.5  121.150002  2280.0  16.92  84.849998           4.31
#
#    mortgage_15yr  cpi  unemployment  federal_budget_deficit  housing_starts  \
# 0           3.39  NaN           NaN                     NaN             NaN
# 1           3.39  NaN           NaN                     NaN             NaN
# 2           3.39  NaN           NaN                     NaN             NaN
#
#    gdp_real  avg_home_price
# 0       NaN             NaN
# 1       NaN             NaN
# 2       NaN             NaN
# (178944, 72)
#
# Resampled to Monthly:
#   symbol       date   adjclose Stock Affect Date    cap GICS Sector ID  \
# 0      A 2013-07-31  29.255550        2013-07-31  large             35
# 1      A 2013-08-30  30.504780        2013-08-30  large             35
# 2      A 2013-09-30  33.597343        2013-09-30  large             35
# 3      A 2013-10-31  33.276123        2013-10-31  large             35
# 4      A 2013-11-29  35.118237        2013-11-29  large             35
#
#    GICS Sector GICS Industry Group ID  \
# 0  Health Care                   3520
# 1  Health Care                   3520
# 2  Health Care                   3520
# 3  Health Care                   3520
# 4  Health Care                   3520
#
#                               GICS Industry Group GICS Industry ID  \
# 0  Pharmaceuticals, Biotechnology & Life Sciences         352030.0
# 1  Pharmaceuticals, Biotechnology & Life Sciences         352030.0
# 2  Pharmaceuticals, Biotechnology & Life Sciences         352030.0
# 3  Pharmaceuticals, Biotechnology & Life Sciences         352030.0
# 4  Pharmaceuticals, Biotechnology & Life Sciences         352030.0
#
#                     GICS Industry GICS Sub-Industry ID  \
# 0  Life Sciences Tools & Services           35203010.0
# 1  Life Sciences Tools & Services           35203010.0
# 2  Life Sciences Tools & Services           35203010.0
# 3  Life Sciences Tools & Services           35203010.0
# 4  Life Sciences Tools & Services           35203010.0
#
#                 GICS Sub-Industry  TotalRevenue  OperatingRevenue  NetIncome  \
# 0  Life Sciences Tools & Services           NaN               NaN        NaN
# 1  Life Sciences Tools & Services           NaN               NaN        NaN
# 2  Life Sciences Tools & Services           NaN               NaN        NaN
# 3  Life Sciences Tools & Services           NaN               NaN        NaN
# 4  Life Sciences Tools & Services      0.039952          0.039952   0.255952
#
#    BasicEPS  DilutedEPS    EBITDA      EBIT  Current Ratio  Quick Ratio  \
# 0       NaN         NaN       NaN       NaN            NaN          NaN
# 1       NaN         NaN       NaN       NaN            NaN          NaN
# 2       NaN         NaN       NaN       NaN            NaN          NaN
# 3       NaN         NaN       NaN       NaN            NaN          NaN
# 4      0.28    0.285714  0.148485  0.188285       0.051757     0.073614
#
#    Gross Profit Margin  Net Profit Margin  Cash Flow Margin  Operating Margin  \
# 0                  NaN                NaN               NaN               NaN
# 1                  NaN                NaN               NaN               NaN
# 2                  NaN                NaN               NaN               NaN
# 3                  NaN                NaN               NaN               NaN
# 4             0.019997           0.207703          0.686125          0.161234
#
#         ROA      CROA       ROE  Efficiency Ratio  Inventory Turnover  \
# 0       NaN       NaN       NaN               NaN                 NaN
# 1       NaN       NaN       NaN               NaN                 NaN
# 2       NaN       NaN       NaN               NaN                 NaN
# 3       NaN       NaN       NaN               NaN                 NaN
# 4  0.207999  0.686539  0.137457         -0.028725           -0.499603
#
#    Debt to Equity  Debt Ratio  Interest Coverage  Cash Flow to Debt  \
# 0             NaN         NaN                NaN                NaN
# 1             NaN         NaN                NaN                NaN
# 2             NaN         NaN                NaN                NaN
# 3             NaN         NaN                NaN                NaN
# 4       -0.095017   -0.038893           0.069456           0.754788
#
#    Assets to Equity  R&D to Revenue  Investment CF to OCF  \
# 0               NaN             NaN                   NaN
# 1               NaN             NaN                   NaN
# 2               NaN             NaN                   NaN
# 3               NaN             NaN                   NaN
# 4         -0.058396        -0.02717             -0.856635
#
#    Financing CF to OCF  FreeCashFlow     Capex  Book Value Per Share  \
# 0                  NaN           NaN       NaN                   NaN
# 1                  NaN           NaN       NaN                   NaN
# 2                  NaN           NaN       NaN                   NaN
# 3                  NaN           NaN       NaN                   NaN
# 4             1.010306       1.12963 -0.396226              0.096854
#
#    Tangible Book Value Per Share  Earnings Call  fed_funds  treasury_10yr  \
# 0                            NaN            NaN       0.09           2.60
# 1                            NaN            1.0       0.07           2.78
# 2                            NaN            NaN       0.06           2.64
# 3                            NaN            NaN       0.07           2.57
# 3  Life Sciences Tools & Services           NaN               NaN        NaN
# 4  Life Sciences Tools & Services      0.039952          0.039952   0.255952
#
#    BasicEPS  DilutedEPS    EBITDA      EBIT  Current Ratio  Quick Ratio  \
# 0       NaN         NaN       NaN       NaN            NaN          NaN
# 1       NaN         NaN       NaN       NaN            NaN          NaN
# 2       NaN         NaN       NaN       NaN            NaN          NaN
# 3       NaN         NaN       NaN       NaN            NaN          NaN
# 4      0.28    0.285714  0.148485  0.188285       0.051757     0.073614
#
#    Gross Profit Margin  Net Profit Margin  Cash Flow Margin  Operating Margin  \
# 0                  NaN                NaN               NaN               NaN
# 1                  NaN                NaN               NaN               NaN
# 2                  NaN                NaN               NaN               NaN
# 3                  NaN                NaN               NaN               NaN
# 4             0.019997           0.207703          0.686125          0.161234
#
#         ROA      CROA       ROE  Efficiency Ratio  Inventory Turnover  \
# 0       NaN       NaN       NaN               NaN                 NaN
# 1       NaN       NaN       NaN               NaN                 NaN
# 2       NaN       NaN       NaN               NaN                 NaN
# 3       NaN       NaN       NaN               NaN                 NaN
# 4  0.207999  0.686539  0.137457         -0.028725           -0.499603
#
#    Debt to Equity  Debt Ratio  Interest Coverage  Cash Flow to Debt  \
# 0             NaN         NaN                NaN                NaN
# 1             NaN         NaN                NaN                NaN
# 2             NaN         NaN                NaN                NaN
# 3             NaN         NaN                NaN                NaN
# 4       -0.095017   -0.038893           0.069456           0.754788
#
#    Assets to Equity  R&D to Revenue  Investment CF to OCF  \
# 0               NaN             NaN                   NaN
# 1               NaN             NaN                   NaN
# 2               NaN             NaN                   NaN
# 3               NaN             NaN                   NaN
# 4         -0.058396        -0.02717             -0.856635
#
#    Financing CF to OCF  FreeCashFlow     Capex  Book Value Per Share  \
# 0                  NaN           NaN       NaN                   NaN
# 1                  NaN           NaN       NaN                   NaN
# 2                  NaN           NaN       NaN                   NaN
# 3                  NaN           NaN       NaN                   NaN
# 4             1.010306       1.12963 -0.396226              0.096854
#
#    Tangible Book Value Per Share  Earnings Call  fed_funds  treasury_10yr  \
# 0                            NaN            NaN        NaN            NaN
# 1                            NaN            1.0  -0.222222       0.069231
# 2                            NaN            NaN  -0.142857      -0.050360
# 3                            NaN            NaN   0.166667      -0.026515
# 4                       0.551626            1.0   0.000000       0.070039
#
#    treasury_2yr  baa_credit_spread  aaa_credit_spread  treasury_3mo       vix  \
# 0           NaN                NaN                NaN           NaN       NaN
# 1      0.258065          -0.044776          -0.039326     -0.333333  0.264684
# 2     -0.153846           0.074219           0.122807     -0.750000 -0.024103
# 3     -0.060606          -0.036364          -0.005208      5.600000 -0.171687
# 4     -0.096774          -0.015094          -0.020942      0.666667 -0.003636
#
#        gold       oil    silver    copper  aluminium  platinum  palladium  \
# 0       NaN       NaN       NaN       NaN        NaN       NaN        NaN
# 1  0.063776  0.024945  0.196054  0.034151        NaN  0.068468  -0.004618
# 2 -0.049853 -0.049419 -0.077015  0.029768        NaN -0.077382   0.005609
# 3 -0.002186 -0.058145  0.008127 -0.007980        NaN  0.026845   0.013909
# 4 -0.055153 -0.037975 -0.084784 -0.019426        NaN -0.053946  -0.024788
#
#    natural_gas     wheat      corn   soybean    coffee     cocao     sugar  \
# 0          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1     0.039176 -0.031615 -0.008016  0.036390 -0.054806  0.050044 -0.037124
# 2    -0.005864  0.054800 -0.108081 -0.099192  0.014273  0.094074  0.069767
# 3     0.005899 -0.016212 -0.030011 -0.001949 -0.072999  0.014015  0.048055
# 4     0.104161 -0.018727 -0.030356  0.043937  0.046015  0.042585 -0.063865
#
#      cotton  mortgage_30yr  mortgage_15yr       cpi  unemployment  \
# 0       NaN            NaN            NaN       NaN           NaN
# 1 -0.022539       0.046404       0.044248  0.001606     -0.026316
# 2  0.028793      -0.042129      -0.048023  0.000891     -0.013514
# 3 -0.103705      -0.050926      -0.050445  0.001803     -0.013699
# 4  0.012438       0.046341       0.031250 -0.000594      0.013889
#
#    federal_budget_deficit  housing_starts  gdp_real  avg_home_price
# 0                     NaN             NaN  0.138079             NaN
# 1                     NaN         0.07177       NaN             NaN
# 2                     NaN        -0.00558       NaN             NaN
# 3                     NaN             NaN       NaN             NaN
# 4                     NaN             NaN       NaN             NaN
# (162174, 72)
#   symbol    cap GICS Sector ID  GICS Sector GICS Industry Group ID  \
# 0      A  large             35  Health Care                   3520
# 2      A  large             35  Health Care                   3520
# 3      A  large             35  Health Care                   3520
#
#                               GICS Industry Group GICS Industry ID  \
# 0  Pharmaceuticals, Biotechnology & Life Sciences         352030.0
# 2  Pharmaceuticals, Biotechnology & Life Sciences         352030.0
# 3  Pharmaceuticals, Biotechnology & Life Sciences         352030.0
#
#                     GICS Industry GICS Sub-Industry ID  \
# 0  Life Sciences Tools & Services           35203010.0
# 2  Life Sciences Tools & Services           35203010.0
# 3  Life Sciences Tools & Services           35203010.0
#
#                 GICS Sub-Industry       date  adjclose  TotalRevenue  \
# 0  Life Sciences Tools & Services 2013-07-31       NaN           NaN
# 2  Life Sciences Tools & Services 2013-09-30  0.101380           NaN
# 3  Life Sciences Tools & Services 2013-10-31 -0.009561           NaN
#
#    OperatingRevenue  NetIncome  BasicEPS  DilutedEPS  EBITDA  EBIT  \
# 0               NaN        NaN       NaN         NaN     NaN   NaN
# 2               NaN        NaN       NaN         NaN     NaN   NaN
# 3               NaN        NaN       NaN         NaN     NaN   NaN
#
#    Current Ratio  Quick Ratio  Gross Profit Margin  Net Profit Margin  \
# 0            NaN          NaN                  NaN                NaN
# 2            NaN          NaN                  NaN                NaN
# 3            NaN          NaN                  NaN                NaN
#
#    Cash Flow Margin  Operating Margin  ROA  CROA  ROE  Efficiency Ratio  \
# 0               NaN               NaN  NaN   NaN  NaN               NaN
# 2               NaN               NaN  NaN   NaN  NaN               NaN
# 3               NaN               NaN  NaN   NaN  NaN               NaN
#
#    Inventory Turnover  Debt to Equity  Debt Ratio  Interest Coverage  \
# 0                 NaN             NaN         NaN                NaN
# 2                 NaN             NaN         NaN                NaN
# 3                 NaN             NaN         NaN                NaN
#
#    Cash Flow to Debt  Assets to Equity  R&D to Revenue  Investment CF to OCF  \
# 0                NaN               NaN             NaN                   NaN
# 2                NaN               NaN             NaN                   NaN
# 3                NaN               NaN             NaN                   NaN
#
#    Financing CF to OCF  FreeCashFlow  Capex  Book Value Per Share  \
# 0                  NaN           NaN    NaN                   NaN
# 2                  NaN           NaN    NaN                   NaN
# 3                  NaN           NaN    NaN                   NaN
#
#    Tangible Book Value Per Share  fed_funds  treasury_10yr  treasury_2yr  \
# 0                            NaN        NaN            NaN           NaN
# 2                            NaN  -0.142857      -0.050360     -0.153846
# 3                            NaN   0.166667      -0.026515     -0.060606
#
#    baa_credit_spread  aaa_credit_spread  treasury_3mo       vix      gold  \
# 0                NaN                NaN           NaN       NaN       NaN
# 2           0.074219           0.122807         -0.75 -0.024103 -0.049853
# 3          -0.036364          -0.005208          5.60 -0.171687 -0.002186
#
#         oil    silver    copper  aluminium  platinum  palladium  natural_gas  \
# 0       NaN       NaN       NaN        NaN       NaN        NaN          NaN
# 2 -0.049419 -0.077015  0.029768        NaN -0.077382   0.005609    -0.005864
# 3 -0.058145  0.008127 -0.007980        NaN  0.026845   0.013909     0.005899
#
#       wheat      corn   soybean    coffee     cocao     sugar    cotton  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2  0.054800 -0.108081 -0.099192  0.014273  0.094074  0.069767  0.028793
# 3 -0.016212 -0.030011 -0.001949 -0.072999  0.014015  0.048055 -0.103705
#
#    mortgage_30yr  mortgage_15yr       cpi  unemployment  \
# 0            NaN            NaN       NaN           NaN
# 2      -0.042129      -0.048023  0.000891     -0.013514
# 3      -0.050926      -0.050445  0.001803     -0.013699
#
#    federal_budget_deficit  housing_starts  gdp_real  avg_home_price
# 0                     NaN             NaN  0.138079             NaN
# 2                     NaN        -0.00558       NaN             NaN
# 3                     NaN             NaN       NaN             NaN
# Nulls:
#  symbol                                0
# cap                                   0
# GICS Sector ID                        0
# GICS Sector                           0
# GICS Industry Group ID                0
# GICS Industry Group                   0
# GICS Industry ID                      0
# GICS Industry                         0
# GICS Sub-Industry ID                  0
# GICS Sub-Industry                     0
# date                                  0
# palladium                          1317
# platinum                           1317
# copper                             1317
# silver                             1317
# oil                                1317
# treasury_2yr                       1317
# vix                                1317
# treasury_3mo                       1317
# aaa_credit_spread                  1317
# baa_credit_spread                  1317
# natural_gas                        1317
# gold                               1317
# wheat                              1317
# cocao                              1317
# soybean                            1317
# coffee                             1317
# treasury_10yr                      1317
# sugar                              1317
# cotton                             1317
# mortgage_30yr                      1317
# mortgage_15yr                      1317
# adjclose                           1317
# corn                               1317
# fed_funds                          1317
# cpi                                3537
# unemployment                       4741
# housing_starts                     6793
# aluminium                         11949
# federal_budget_deficit            35729
# gdp_real                         112926
# avg_home_price                   120480
# Book Value Per Share             126096
# TotalRevenue                     126096
# OperatingRevenue                 126096
# NetIncome                        126096
# EBITDA                           126096
# EBIT                             126096
# Current Ratio                    126096
# Gross Profit Margin              126096
# Net Profit Margin                126096
# Cash Flow Margin                 126096
# Operating Margin                 126096
# Tangible Book Value Per Share    126096
# CROA                             126096
# ROA                              126096
# Debt to Equity                   126096
# Debt Ratio                       126096
# Cash Flow to Debt                126096
# Assets to Equity                 126096
# Investment CF to OCF             126096
# Financing CF to OCF              126096
# FreeCashFlow                     126096
# Capex                            126096
# ROE                              126096
# DilutedEPS                       127164
# BasicEPS                         127164
# Efficiency Ratio                 129370
# Interest Coverage                129489
# Quick Ratio                      134493
# Inventory Turnover               138889
# R&D to Revenue                   150949
# dtype: int64

# %%
# Drop dates outside of the date range
df = df[(df['date'] >= DATE_START) &
        (df['date'] <= DATE_END)]
print('In Range:', df.shape)

# Display null adjusted close dates
display(df[df['adjclose'].isnull()])
# Out:
# In Range: (154512, 72)
#        symbol    cap GICS Sector ID             GICS Sector  \
# 1408     ABNB  large             25  Consumer Discretionary
# 3175     ADNT    mid             25  Consumer Discretionary
# 5056     AGTI  small             35             Health Care
# 5219     AHCO  small             35             Health Care
# 5801     AIRC    mid             60             Real Estate
# ...       ...    ...            ...                     ...
# 176864    XHR  small             60             Real Estate
# 177224   XPEL  small             25  Consumer Discretionary
# 177280   XPER  small             45  Information Technology
# 177938   YETI    mid             25  Consumer Discretionary
# 178643     ZI    mid             50  Communication Services
#
#        GICS Industry Group ID                           GICS Industry Group  \
# 1408                     2530                             Consumer Services
# 3175                     2510                      Automobiles & Components
# 5056                     3510              Health Care Equipment & Services
# 5219                     3510              Health Care Equipment & Services
# 5801                     6010  Equity Real Estate Investment Trusts (REITs)
# ...                       ...                                           ...
# 176864                   6010  Equity Real Estate Investment Trusts (REITs)
# 177224                   2510                      Automobiles & Components
# 177280                   4530      Semiconductors & Semiconductor Equipment
# 177938                   2520                   Consumer Durables & Apparel
# 178643                   5020                         Media & Entertainment
#
#        GICS Industry ID                             GICS Industry  \
# 1408           253010.0             Hotels, Restaurants & Leisure
# 3175           251010.0                     Automobile Components
# 5056           351020.0          Health Care Providers & Services
# 5219           351010.0          Health Care Equipment & Supplies
# 5801           601060.0                         Residential REITs
# ...                 ...                                       ...
# 176864         601030.0                      Hotel & Resort REITs
# 177224         251010.0                     Automobile Components
# 177280         453010.0  Semiconductors & Semiconductor Equipment
# 177938         252020.0                          Leisure Products
# 178643         502030.0              Interactive Media & Services
#
#        GICS Sub-Industry ID                    GICS Sub-Industry       date  \
# 1408             25301020.0       Hotels, Resorts & Cruise Lines 2020-12-31
# 3175             25101010.0         Automotive Parts & Equipment 2016-10-31
# 5056             35102015.0                 Health Care Services 2021-04-30
# 5219             35101010.0                Health Care Equipment 2018-05-31
# 5801             60106010.0       Multi-Family Residential REITs 2020-12-31
# ...                     ...                                  ...        ...
# 176864           60103010.0                 Hotel & Resort REITs 2015-02-27
# 177224           25101010.0         Automotive Parts & Equipment 2019-07-31
# 177280           45301010.0  Semiconductor Materials & Equipment 2022-09-30
# 177938           25202010.0                     Leisure Products 2018-10-31
# 178643           50203010.0         Interactive Media & Services 2020-06-30
#
#         adjclose  TotalRevenue  OperatingRevenue  NetIncome  BasicEPS  \
# 1408         NaN           NaN               NaN        NaN       NaN
# 3175         NaN           NaN               NaN        NaN       NaN
# 5056         NaN           NaN               NaN        NaN       NaN
# 5219         NaN           NaN               NaN        NaN       NaN
# 5801         NaN           NaN               NaN        NaN       NaN
# ...          ...           ...               ...        ...       ...
# 3175                     NaN                  NaN           NaN    NaN
# 5056                     NaN                  NaN           NaN    NaN
# 5219                     NaN                  NaN           NaN    NaN
# 5801                     NaN                  NaN           NaN    NaN
# ...                      ...                  ...           ...    ...
# 176864                   NaN                  NaN           NaN    NaN
# 177224                   NaN                  NaN           NaN    NaN
# 177280                   NaN                  NaN           NaN    NaN
# 177938                   NaN                  NaN           NaN    NaN
# 178643                   NaN                  NaN           NaN    NaN
#
#         Book Value Per Share  Tangible Book Value Per Share  fed_funds  \
# 1408                     NaN                            NaN        NaN
# 3175                     NaN                            NaN        NaN
# 5056                     NaN                            NaN        NaN
# 5219                     NaN                            NaN        NaN
# 5801                     NaN                            NaN        NaN
# ...                      ...                            ...        ...
# 176864                   NaN                            NaN        NaN
# 177224                   NaN                            NaN        NaN
# 177280                   NaN                            NaN        NaN
# 177938                   NaN                            NaN        NaN
# 178643                   NaN                            NaN        NaN
#
#         treasury_10yr  treasury_2yr  baa_credit_spread  aaa_credit_spread  \
# 1408              NaN           NaN                NaN                NaN
# 3175              NaN           NaN                NaN                NaN
# 5056              NaN           NaN                NaN                NaN
# 5219              NaN           NaN                NaN                NaN
# 5801              NaN           NaN                NaN                NaN
# ...               ...           ...                ...                ...
# 176864            NaN           NaN                NaN                NaN
# 177224            NaN           NaN                NaN                NaN
# 177280            NaN           NaN                NaN                NaN
# 177938            NaN           NaN                NaN                NaN
# 178643            NaN           NaN                NaN                NaN
#
#         treasury_3mo  vix  gold  oil  silver  copper  aluminium  platinum  \
# 1408             NaN  NaN   NaN  NaN     NaN     NaN        NaN       NaN
# 3175             NaN  NaN   NaN  NaN     NaN     NaN        NaN       NaN
# 5056             NaN  NaN   NaN  NaN     NaN     NaN        NaN       NaN
# 5219             NaN  NaN   NaN  NaN     NaN     NaN        NaN       NaN
# 5801             NaN  NaN   NaN  NaN     NaN     NaN        NaN       NaN
# ...              ...  ...   ...  ...     ...     ...        ...       ...
# 176864           NaN  NaN   NaN  NaN     NaN     NaN        NaN       NaN
# 177224           NaN  NaN   NaN  NaN     NaN     NaN        NaN       NaN
# 177280           NaN  NaN   NaN  NaN     NaN     NaN        NaN       NaN
# 177938           NaN  NaN   NaN  NaN     NaN     NaN        NaN       NaN
# 178643           NaN  NaN   NaN  NaN     NaN     NaN        NaN       NaN
#
#         palladium  natural_gas  wheat  corn  soybean  coffee  cocao  sugar  \
# 1408          NaN          NaN    NaN   NaN      NaN     NaN    NaN    NaN
# 3175          NaN          NaN    NaN   NaN      NaN     NaN    NaN    NaN
# 5056          NaN          NaN    NaN   NaN      NaN     NaN    NaN    NaN
# 5219          NaN          NaN    NaN   NaN      NaN     NaN    NaN    NaN
# 5801          NaN          NaN    NaN   NaN      NaN     NaN    NaN    NaN
# ...           ...          ...    ...   ...      ...     ...    ...    ...
# 176864        NaN          NaN    NaN   NaN      NaN     NaN    NaN    NaN
# 177224        NaN          NaN    NaN   NaN      NaN     NaN    NaN    NaN
# 177280        NaN          NaN    NaN   NaN      NaN     NaN    NaN    NaN
# 177938        NaN          NaN    NaN   NaN      NaN     NaN    NaN    NaN
# 178643        NaN          NaN    NaN   NaN      NaN     NaN    NaN    NaN
#
#         cotton  mortgage_30yr  mortgage_15yr       cpi  unemployment  \
# 1408       NaN            NaN            NaN  0.001890           NaN
# 3175       NaN            NaN            NaN  0.002900           NaN
# 5056       NaN            NaN            NaN       NaN           NaN
# 5219       NaN            NaN            NaN       NaN           NaN
# 5801       NaN            NaN            NaN       NaN           NaN
# ...        ...            ...            ...       ...           ...
# 176864     NaN            NaN            NaN -0.006233      0.017857
# 177224     NaN            NaN            NaN  0.000588      0.027778
# 177280     NaN            NaN            NaN       NaN           NaN
# 177938     NaN            NaN            NaN       NaN           NaN
# 178643     NaN            NaN            NaN -0.000524     -0.095238
#
#         federal_budget_deficit  housing_starts  gdp_real  avg_home_price
# 1408                  0.488626        0.011111       NaN             NaN
# 3175                       NaN       -0.083187  0.007662       -0.007971
# 5056                       NaN             NaN  0.016360        0.026189
# 5219                       NaN             NaN       NaN             NaN
# 5801                       NaN        0.011111       NaN             NaN
# ...                        ...             ...       ...             ...
# 176864                     NaN       -0.022039       NaN             NaN
# 177224                0.959204       -0.012608  0.005895        0.004509
# 177280                     NaN        0.089212       NaN             NaN
# 177938                     NaN             NaN  0.008877             NaN
# 178643                0.459483        0.093154       NaN             NaN
#
# [221 rows x 72 columns]

# %%
# Drop null adjusted close
df = df[df['adjclose'].notnull()]

# Replace inf with nan
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# Get the number of companies in each cap
print('\nCompany Counts:\n', df.groupby(
    'cap', observed=True)['symbol'].nunique())

# Display nulls
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df.isnull().sum().sort_values())

display(df.head(3))
df.to_csv('data/preprocessed.csv', index=False)
# Out:
# Company Counts:
#  cap
# large    498
# mid      396
# small    598
# Name: symbol, dtype: int64
# symbol                                0
# coffee                                0
# soybean                               0
# corn                                  0
# wheat                                 0
# natural_gas                           0
# palladium                             0
# platinum                              0
# treasury_10yr                         0
# copper                                0
# oil                                   0
# gold                                  0
# vix                                   0
# treasury_3mo                          0
# aaa_credit_spread                     0
# baa_credit_spread                     0
# treasury_2yr                          0
# silver                                0
# sugar                                 0
# cocao                                 0
# mortgage_30yr                         0
# cap                                   0
# GICS Sector ID                        0
# GICS Sector                           0
# GICS Industry Group ID                0
# GICS Industry Group                   0
# GICS Industry ID                      0
# GICS Industry                         0
# cotton                                0
# GICS Sub-Industry ID                  0
# date                                  0
# adjclose                              0
# mortgage_15yr                         0
# GICS Sub-Industry                     0
# fed_funds                             0
# cpi                                2331
# unemployment                       3473
# housing_starts                     3740
# aluminium                          5526
# federal_budget_deficit            29365
# gdp_real                         106198
# avg_home_price                   112649
# Book Value Per Share             118895
# TotalRevenue                     118895
# OperatingRevenue                 118895
# NetIncome                        118895
# EBITDA                           118895
# EBIT                             118895
# Current Ratio                    118895
# Gross Profit Margin              118895
# Net Profit Margin                118895
# Cash Flow Margin                 118895
# Operating Margin                 118895
# Tangible Book Value Per Share    118895
# CROA                             118895
# ROA                              118895
# Debt to Equity                   118895
# Debt Ratio                       118895
# Cash Flow to Debt                118895
# Assets to Equity                 118895
# Investment CF to OCF             118895
# Financing CF to OCF              118895
# FreeCashFlow                     118895
# Capex                            118895
# ROE                              118895
# DilutedEPS                       119887
# BasicEPS                         119887
# Efficiency Ratio                 122102
# Interest Coverage                122220
# Quick Ratio                      127132
# Inventory Turnover               131454
# R&D to Revenue                   143261
# dtype: int64
#   symbol    cap GICS Sector ID  GICS Sector GICS Industry Group ID  \
# 6      A  large             35  Health Care                   3520
# 7      A  large             35  Health Care                   3520
# 8      A  large             35  Health Care                   3520
#
#                               GICS Industry Group GICS Industry ID  \
# 6  Pharmaceuticals, Biotechnology & Life Sciences         352030.0
# 7  Pharmaceuticals, Biotechnology & Life Sciences         352030.0
# 8  Pharmaceuticals, Biotechnology & Life Sciences         352030.0
#
#                     GICS Industry GICS Sub-Industry ID  \
# 6  Life Sciences Tools & Services           35203010.0
# 7  Life Sciences Tools & Services           35203010.0
# 8  Life Sciences Tools & Services           35203010.0
#
#                 GICS Sub-Industry       date  adjclose  TotalRevenue  \
# 6  Life Sciences Tools & Services 2014-01-31  0.016787           NaN
# 7  Life Sciences Tools & Services 2014-02-28 -0.020980     -0.413271
# 8  Life Sciences Tools & Services 2014-03-31 -0.017741           NaN
#
#    OperatingRevenue  NetIncome  BasicEPS  DilutedEPS    EBITDA      EBIT  \
# 6               NaN        NaN       NaN         NaN       NaN       NaN
# 7         -0.413271  -0.075829 -0.078125   -0.079365 -0.414248 -0.556338
# 8               NaN        NaN       NaN         NaN       NaN       NaN
#
#    Current Ratio  Quick Ratio  Gross Profit Margin  Net Profit Margin  \
# 6            NaN          NaN                  NaN                NaN
# 7       0.052895      0.05217            -0.042702           0.575124
# 8            NaN          NaN                  NaN                NaN
#
#    Cash Flow Margin  Operating Margin       ROA      CROA       ROE  \
# 6               NaN               NaN       NaN       NaN       NaN
# 7         -0.122953         -0.258452 -0.071659 -0.483089 -0.102637
# 8               NaN               NaN       NaN       NaN       NaN
#
#    Efficiency Ratio  Inventory Turnover  Debt to Equity  Debt Ratio  \
# 6               NaN                 NaN             NaN         NaN
# 7          0.038654            0.646016       -0.030446    0.003023
# 8               NaN                 NaN             NaN         NaN
#
#    Interest Coverage  Cash Flow to Debt  Assets to Equity  R&D to Revenue  \
# 6                NaN                NaN               NaN             NaN
# 7          -0.541039          -0.484647         -0.033368        -0.13304
# 8                NaN                NaN               NaN             NaN
#
#    Investment CF to OCF  Financing CF to OCF  FreeCashFlow    Capex  \
# 6                   NaN                  NaN           NaN      NaN
# 7              0.441616           -23.024055     -0.568116  0.40625
# 8                   NaN                  NaN           NaN      NaN
#
#    Book Value Per Share  Tangible Book Value Per Share  fed_funds  \
# 6                   NaN                            NaN   0.000000
# 7              0.028574                        0.18369  -0.142857
# 8                   NaN                            NaN   0.000000
#
#    treasury_10yr  treasury_2yr  baa_credit_spread  aaa_credit_spread  \
# 6      -0.121711     -0.105263           0.030043           0.150327
# 7      -0.003745     -0.029412          -0.020833          -0.056818
# 8       0.026316      0.333333          -0.038298          -0.042169
#
#    treasury_3mo       vix      gold       oil    silver    copper  aluminium  \
# 6     -0.841270  0.341837  0.031783 -0.009449 -0.012100 -0.064216        NaN
# 7      3.300000 -0.239544  0.065559  0.052313  0.109867  0.005589        NaN
# 8     -0.348837 -0.008571 -0.028757 -0.009845 -0.069327 -0.059287        NaN
#
#    platinum  palladium  natural_gas     wheat      corn   soybean    coffee  \
# 6  0.002188  -0.020073     0.168558 -0.081784  0.028436 -0.022667  0.130985
# 7  0.052471   0.058108    -0.067570  0.077823  0.054147  0.102514  0.436102
# 8 -0.019154   0.045238    -0.051638  0.164023  0.097268  0.035178 -0.010567
#
#       cocao     sugar    cotton  mortgage_30yr  mortgage_15yr       cpi  \
# 6  0.074566 -0.052407  0.014060      -0.035714      -0.034091  0.002972
# 7  0.008245  0.059164  0.008855       0.011574      -0.002941  0.001496
# 8  0.006814  0.078931  0.080032       0.006865       0.008850  0.001005
#
#    unemployment  federal_budget_deficit  housing_starts  gdp_real  \
# 6     -0.042857                     NaN       -0.084326  0.020251
# 7     -0.014925                     NaN       -0.119119       NaN
# 8      0.015152                     NaN        0.030682       NaN
#
#    avg_home_price
# 6             NaN
# 7             NaN
# 8             NaN
